# %% [markdown]
# # Tutorial 3 Parsing Excel Files
#
# So far, you have learnt how to work with data in the formats that are machine readable,
# such as CSV, JSON and XML.
# The approaches used to import data in those formats are generally standard.
# However, not all data can easily be imported into Python or other programming languages without
# a fair amount of work.
# For example, with data stored in spreadsheets and PDFs.
# In these circumstances, data is generated purely for human consumption.
# The person who generated the data often tries to make it easily readable for human,
# disregarding the importance of releasing it in a machine readable format.
#
# We will provide some generic instructions on how to scrape data from excel files.
# You will find that the scraping process becomes much more difficult and time-consuming.
# But the ultimate goal stays the same, i.e., extracting data and converting it into a machine readable format.
# * * *
#
# ## 1. Introduction to Excel
#
# Excel is a popular spreadsheet application originally
# developed for Windows.
# You can also find free alternatives that run on Mac OS and Linux,
# for example, LibreOffice Calc and OpenOffice Calc can both work with Excel files.
# An Excel document is also called a workbook.
# It is usually saved in a file with either .xlsx extension or .xls extension,
# depending on the Excel version you use.
# A workbook can contain multiple worksheets, each of which is a grid of cells
# where you keep and manipulate the data.
# Those cells are arranged in numbered rows and letter-named columns.
# Excel can display not only tabular data but also data like line graphs, histograms and charts.
# It also provides a set of data analysis functions for statistical, engineering and financial needs.
# Presumably, most of you know what a Excel file looks like.
# If not, please find some Excel files online and have a look or open the Excel file used in this tutorial.
#
# There are many ways of manipulating data stored in Excel spreadsheets.
# For instance,
# "[Working with Excel Files in Python](http://www.python-excel.org/)" contains pointers to
# the best information available about working with Excel files in Python.
# The website lists the following Python packages that deal with Excel:
#
# * `openpyxl`: Reads/writes Excel 2010 xlsx/xlsm/xltx/xltm files.
# * `xlsxwriter`: write text, numbers, formulas and hyperlinks to multiple worksheets in an Excel 2007+ XLSX file.
# * `xlrd`: Extracts data from Excel files (.xls and .xlsx, versions 2.0 onwards).
# * `xlwt`: Writes and formats Excel files compatible with Microsoft Excel versions 95 to 2003.
# * `xlutils`: Contains a set of advanced tools for manipulating Excel files (requires `xlrd` and `xlwt`).
#
# You would need to install each separately if you want to use them;
# however, in this tutorial we will use Pandas `ExcelFile` class that requires `xlrd` to demonstrate how to
# parse Excel files.
#
# Some tutorials on working with Excel files that might be of your interest:
# * [Working with Excel Spreadsheets](https://automatetheboringstuff.com/chapter12/): It utilizes openyxl to read
# data from spreadsheets. Read the following sections:
#     * Reading Excel Documents 📖
#     * Project: Reading Data from a Spreadsheet 📖
# * [How to read Excel files with Python (xlrd tutorial)](https://www.youtube.com/watch?v=p0DNcTnreuY):
# a Youtube video on extracting data from a simple Excel file. (Optional)
#
#
# This tutorial will use a running example to show
# you how to extract data from Excel spreadsheets step-by-step using Pandas.
# The example we use in this tutorial is "[Table 2: Nutrition](http://www.unicef.org/sowc2014/numbers/documents/excel/SOWC%202014%20Stat%20Tables_Table%202.xlsx)" from Unicef's report on
# [The State of the Worlds Children](http://www.unicef.org/sowc2014/numbers/) for 2014.
# The download link is located at the bottom of the webpage.
# Please download the Excel file, and store it in the same folder as where
# the notebook located.
#
# Our task is to extract the statistic data table on the child's issues of
# underweight, stunting, wasting and overweight prevalence in different countries.
# * * *

# %% [markdown]
# ## 2. Parsing Excel with Pandas
# In this section we will walk through the process of parsing our example Excel file with Pandas.
# A short tutorial on how to use Pandas `read_excel` function and the ExcelFile class  can
# be found at Pandas [webpage on IO](http://pandas.pydata.org/pandas-docs/stable/io.html#io-excel-reader). 📖  (Just read the section "Reading Excel Files".)
#
# Before we start parsing our Excel file,
# we need to first make sure the Python package `xlrd` is installed,
# as Pandas `ExcelFile` class makes use of `xlrd`.
# The `xlrd` package can be run on Linux and Mac as well as Windows.
# Here we assume you use either Linux or Mac.
# If you use Anaconda, you do not need to worry about this,
# as Anaconda includes the most popular Python packages for data analysis, including `xlrd`.
# Otherwise, you might need to install `xlrd` in order to run `read_excel`.
# To install `xlrd`, you can use [pip](https://pypi.python.org/pypi/pip),
# a Python package management system.
# In your command line, simply type
# ```shell
#     pip install xlrd
# ```
#
# Now to start our script,
# we need to import Pandas
# and open our Excel file by creating a Pandas `ExcelFile` object.

# %%
import pandas as pd
excel_data = pd.ExcelFile('SOWC 2014 Stat Tables_Table 2.xlsx')
excel_data

# %% [markdown]
# By running the code above, we have loaded the Excel file as a Pandas' ExcelFile object into Python.
#
# Are we ready to parse our Excel File? Before starting to parse the file,
# we probably need to ask ourselves a couple of questions. For instance,
# * How many sheets does our Excel file have?
# * Which data sheet does contain our data? What is the name of the sheet? Or what is the index of the sheet?

# %% [markdown]
# Unlike CSV files, an Excel file can have multiple worksheets.
# For example, our Excel file contains two worksheets, one contains data notes,
# and the other contains the data we want.
# In order to get our data, we will just pull the sheet with the data we want.
#
# If your Excel file has a couple of worksheets and you can guess the index of
# the worksheet that contains the data you want, or you have been told from which
# worksheet you are going to extract data, you can directly use Panda's
# [`read_excel`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html#pandas.read_excel)
# fuction
# ```python
#     pandas.read_excel()
# ```
# This function reads an Excel table in a given worksheet into a Pandas DataFrame,
# where you can start further manipulating the data.
#
# However, in some cases, particularly while an Excel file has a lot of worksheets,
# it might be good to view all the sheets by their names.
# So, let's check out what the names of the sheets we have in our Excel file are:

# %%
excel_data.sheet_names
# Out:
# ['Data Notes', 'Table 2 ']

# %% [markdown]
# There are two worksheets in our Excel file.
# The one that we are looking for is "Table 2 ".
# So, let's read the second worksheet into a Pandas DataFrame.
# Note that there is an extra space in the worksheet name.
# Without this space, running the following parsing code
# will result in the following error
# ```
#     XLRDError: No sheet named <'Table 2'>
# ```

# %%
df = excel_data.parse('Table 2 ')
#df.head()
df.tail()
#df.shape
# Out:
#     TABLE 2. NUTRITION Unnamed: 1  \
# NaN                NaN        NaN
# NaN                NaN        NaN
# NaN                NaN        NaN
# NaN                NaN        NaN
# NaN                NaN        NaN
#
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# NaN  Bajo peso al nacer – Encuestas de Demografía y...        NaN        NaN
# NaN  Lactancia materna – DHS, MICS, otras encuestas...        NaN        NaN
# NaN  Insuficiencia ponderal, emaciación, cortedad d...        NaN        NaN
# NaN                Suplementos de vitamina A – UNICEF.        NaN        NaN
# NaN  Consumo de sal yodada – DHS, MICS, otras encue...        NaN        NaN
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...      \
# NaN        NaN        NaN        NaN        NaN        NaN     ...
# NaN        NaN        NaN        NaN        NaN        NaN     ...
# NaN        NaN        NaN        NaN        NaN        NaN     ...
# NaN        NaN        NaN        NaN        NaN        NaN     ...
# NaN        NaN        NaN        NaN        NaN        NaN     ...
#
#     Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# NaN         NaN         NaN         NaN         NaN         NaN         NaN
# NaN         NaN         NaN         NaN         NaN         NaN         NaN
# NaN         NaN         NaN         NaN         NaN         NaN         NaN
# NaN         NaN         NaN         NaN         NaN         NaN         NaN
# NaN         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27
# NaN         NaN         NaN         NaN         NaN
# NaN         NaN         NaN         NaN         NaN
# NaN         NaN         NaN         NaN         NaN
# NaN         NaN         NaN         NaN         NaN
# NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# We have loaded the target worksheet into Python.
# There are 322 rows and 28 columns (You can use `df.shape` to
# see the dimensionality of the DataFrame).
#
# If you scroll through the output, you will notice that the loaded data table is quite messy.
# The messiness includes
# * Rows only contain missing values that are indicated by NaN in Pandas DataFrame.
# * Column heads are in three languages, i.e., English, French and Spanish.
# * Column heads in one language spread over multiple rows.
# * Country names also appear in three languages.
# * Notes shown in the original Excel file appear in rows towards the end of the data frame.
#
# Remember that our goal is to extract the data table in English.
# It is clear that we need to further process the data frame.
# For demonstration purpose,
# we will try to keep the example as simple as possible,
# so we will not extract column heads here.
# Instead, if you are interested in programmatically extracting column heads,
# you can try it by yourself.

# %% [markdown]
# ### Task 1 Drop useless columns and rows
#
# We will start with removing country names in French and Spanish,
# which corresponds to remove **two columns, labeled "Unnamed: 1" and "Unnamed: 2" ** in our data frame.
# To do this, we are going to use DataFrame's [`drop()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html) function,
# which returns a new object with labels in requested axis removed.
# We will frequently use this function later in this section.
#
# Have a try now:

# %%
df = df.drop(['Unnamed: 1', 'Unnamed: 2'], 1)
df.shape
# Out:
# (322, 26)

# %% [markdown]
# Now you should have 26 columns.
# Next we are going to remove all the rows and columns that are empty, i.e., only contains NaNs. We will need to use [dropna()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html) function.
#
# Fill you code here:

# %%
df = df.dropna(0, how = 'all')
df = df.dropna(1, how = 'all')
df
# Out:
#                                     TABLE 2. NUTRITION  \
# NaN                                Countries and areas
# NaN                                                NaN
# NaN                                                NaN
# NaN                                    FRENCH HEADINGS
# NaN                                                NaN
# NaN                                                NaN
# NaN                                   SPANISH HEADINGS
# NaN                                                NaN
# NaN                                                NaN
# NaN                                        Afghanistan
# NaN                                            Albania
# NaN                                            Algeria
# NaN                                            Andorra
# NaN                                             Angola
# NaN                                Antigua and Barbuda
# NaN                                          Argentina
# NaN                                            Armenia
# NaN                                          Australia
# NaN                                            Austria
# NaN                                         Azerbaijan
# NaN                                            Bahamas
# NaN                                            Bahrain
# NaN                                         Bangladesh
# NaN                                           Barbados
# NaN                                            Belarus
# NaN                                            Belgium
# NaN                                             Belize
# NaN                                              Benin
# NaN                                             Bhutan
# NaN                   Bolivia (Plurinational State of)
# ..                                                 ...
# NaN                          Least developed countries
# NaN                                              World
# NaN  # For a complete list of countries and areas i...
# NaN                                              NOTES
# NaN                              – Data not available.
# NaN  w Identifies countries with national vitamin A...
# NaN  x Data refer to years or periods other than th...
# NaN  y Data differ from the standard definition or ...
# NaN  Δ Full coverage with vitamin A supplements is ...
# NaN  * Data refer to the most recent year available...
# NaN                                 ** Excludes China.
# NaN  θ Regional averages for underweight (moderate ...
# NaN                      DEFINITIONS OF THE INDICATORS
# NaN  Low birthweight – Percentage of infants weighi...
# NaN  Early initiation of breastfeeding – Percentage...
# NaN  Exclusive breastfeeding <6 months – Percentage...
# NaN  Introduction of solid, semi-solid or soft food...
# NaN  Breastfeeding at age 2 – Percentage of childre...
# NaN  Underweight – Moderate and severe: Percentage ...
# NaN  Stunting – Moderate and severe: Percentage of ...
# NaN  Wasting – Moderate and severe: Percentage of c...
# NaN  Overweight – Moderate and severe: Percentage o...
# NaN  Vitamin A supplementation, full coverage – The...
# NaN  Iodized salt consumption – Percentage of house...
# NaN                                  MAIN DATA SOURCES
# NaN  Low birthweight – Demographic and Health Surve...
# NaN  Breastfeeding – DHS, MICS, other national hous...
# NaN  Underweight, stunting, wasting and overweight ...
# NaN                Vitamin A supplementation – UNICEF.
# NaN  Iodized salt consumption – DHS, MICS, other na...
#
#                                          Unnamed: 3 Unnamed: 4  \
# NaN                             Low birthweight (%)        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN  Insuffisance\npondérale à la\nnaissance\n(%)\n        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN                         Bajo peso al nacer (%)         NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN                                               –        NaN
# NaN                                             3.6        NaN
# NaN                                               6          x
# NaN                                               –        NaN
# NaN                                              12          x
# NaN                                               5          x
# NaN                                             7.2        NaN
# NaN                                               8        NaN
# NaN                                               7          x
# NaN                                               7          x
# NaN                                              10          x
# NaN                                              11          x
# NaN                                               –        NaN
# NaN                                              22          x
# NaN                                            11.8        NaN
# NaN                                               4          x
# NaN                                               –        NaN
# NaN                                            11.1        NaN
# NaN                                              15          x
# NaN                                             9.9        NaN
# NaN                                               6        NaN
# ..                                              ...        ...
# NaN                                         12.8291        NaN
# NaN                                         14.6574        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
#
#                                          Unnamed: 5 Unnamed: 6  \
# NaN           Early initiation of breastfeeding (%)        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN      Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# NaN                                             NaN        NaN
# NaN                                      2008−2012*        NaN
# NaN  Iniciación temprana a la lactancia materna (%)        NaN
# NaN                                             NaN        NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
#
#                        Unnamed: 25 Unnamed: 26
# NaN   Iodized salt consumption (%)         NaN
# NaN                            NaN         NaN
# NaN                     2008–2012*         NaN
# NaN  Consommation\nde sel iodé (%)         NaN
# NaN                            NaN         NaN
# NaN                     2008–2012*         NaN
# NaN      Consumo de sal yodada (%)         NaN
# NaN                            NaN         NaN
# NaN                     2008–2012*         NaN
# NaN                           20.4         NaN
# NaN                           75.6         NaN
# NaN                           60.7           x
# NaN                              –         NaN
# NaN                           44.7           x
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                             97           x
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                           53.8           x
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                           82.3           y
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                             86         NaN
# NaN                           96.2         x,y
# NaN                           88.7           y
# ..                             ...         ...
# NaN                        60.2242         NaN
# NaN                        75.5568         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
#
# [245 rows x 25 columns]

# %% [markdown]
# The printout shows that the very first column in the data frame only contains NaNs.
# These NaNs are row indices. We would like to work with row index to delete other useless rows, hence we need to reset the row indices with a list of integers.

# %%
df.index = range(len(df.index))
df.head()
# Out:
#     TABLE 2. NUTRITION                                      Unnamed: 3  \
# 0  Countries and areas                             Low birthweight (%)
# 1                  NaN                                             NaN
# 2                  NaN                                      2008–2012*
# 3      FRENCH HEADINGS  Insuffisance\npondérale à la\nnaissance\n(%)\n
# 4                  NaN                                             NaN
#
#   Unnamed: 4                                  Unnamed: 5 Unnamed: 6  \
# 0        NaN       Early initiation of breastfeeding (%)        NaN
# 1        NaN                                         NaN        NaN
# 2        NaN                                  2008–2012*        NaN
# 3        NaN  Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# 4        NaN                                         NaN        NaN
#
#                                          Unnamed: 7 Unnamed: 8  \
# 0            Exclusive breastfeeding\n<6 months (%)        NaN
# 1                                               NaN        NaN
# 2                                               NaN        NaN
# 3  Allaitement\nexclusivement\nau sein <6 mois\n(%)        NaN
# 4                                               NaN        NaN
#
#                                           Unnamed: 9 Unnamed: 10  \
# 0  Introduction of solid, semi-solid or soft food...         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3  Introduction\nd’aliments\nsolides, semisolides...         NaN
# 4                                                NaN         NaN
#
#                               Unnamed: 11     ...      \
# 0              Breastfeeding at age 2 (%)     ...
# 1                                     NaN     ...
# 2                                     NaN     ...
# 3  Nourris au sein\nà l’âge de\n2 ans (%)     ...
# 4                                     NaN     ...
#
#                    Unnamed: 17 Unnamed: 18             Unnamed: 19  \
# 0                 Stunting (%)         NaN             Wasting (%)
# 1       moderate \nand severeθ         NaN  moderate \nand severeθ
# 2                          NaN         NaN                     NaN
# 3  Retard de\ncroissance (%)\n         NaN        Émaciation (%)\n
# 4            modérée et graveθ         NaN       modérée et graveθ
#
#   Unnamed: 20           Unnamed: 21 Unnamed: 22  \
# 0         NaN        Overweight (%)         NaN
# 1         NaN  moderate and severeθ         NaN
# 2         NaN                   NaN         NaN
# 3         NaN        Surpoids (%)\n         NaN
# 4         NaN     modérée et graveθ         NaN
#
#                                          Unnamed: 23 Unnamed: 24  \
# 0      Vitamin A supplementation, full coverageΔ (%)         NaN
# 1                                                NaN         NaN
# 2                                               2012         NaN
# 3  Couverture\ntotale par la\nsupplémentation en\...         NaN
# 4                                                NaN         NaN
#
#                      Unnamed: 25 Unnamed: 26
# 0   Iodized salt consumption (%)         NaN
# 1                            NaN         NaN
# 2                     2008–2012*         NaN
# 3  Consommation\nde sel iodé (%)         NaN
# 4                            NaN         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# After resetting all the row indices, and if you print out the
# first 15 rows using the slicing method:
# ```
#     df[:15]
# ```
# You will find that the data we want starts from row index 9.
# The first 9 rows contain column heads in three different languages.
# As we mentioned before, to keep our script simple, we will not extract column heads here,
# rather we will delete them.
#
# Similarly, if we print out the last 50 rows,
# ```
#     df[-50:]
# ```
# The data we want ends at row 205.
# Therefore, we need to delete the first 9 rows and the
# last 39 rows, and then reindex all the rows left.
#
#
# To do this task you will need to use [drop()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html) function

# %%
# Delete the first 9 rows
df = df.drop(df.index[0:9])
# Delete the last 39 rows
df = df.drop(df.index[-39:])
# Reindex rows
df.index = range(len(df.index))
df
# Out:
#                    TABLE 2. NUTRITION Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                             Austria          7          x          –
# 1                          Azerbaijan         10          x       31.9
# 2                             Bahamas         11          x          –
# 3                             Bahrain          –        NaN          –
# 4                          Bangladesh         22          x       47.1
# 5                            Barbados       11.8        NaN          –
# 6                             Belarus          4          x       21.1
# 7                             Belgium          –        NaN          –
# 8                              Belize       11.1        NaN       61.5
# 9                               Benin         15          x       50.4
# 10                             Bhutan        9.9        NaN         59
# 11   Bolivia (Plurinational State of)          6        NaN       63.8
# 12             Bosnia and Herzegovina        3.1        NaN       42.3
# 13                           Botswana         13          x         40
# 14                             Brazil       8.39        NaN       67.7
# 15                  Brunei Darussalam          –        NaN          –
# 16                           Bulgaria        8.8        NaN          –
# 17                       Burkina Faso       14.1        NaN       42.1
# 18                            Burundi       12.9        NaN       73.6
# 19                         Cabo Verde          6          x       72.7
# 20                           Cambodia       11.3        NaN       65.8
# 21                           Cameroon         11          x       19.6
# 22                             Canada          6          x          –
# 23          Central African Republic        13.7        NaN       43.5
# 24                               Chad       19.9        NaN       28.7
# 25                              Chile        5.9        NaN          –
# 26                              China          3        NaN         41
# 27                           Colombia          6          x       48.9
# 28                            Comoros         25          x       24.9
# 29                              Congo         13          x       38.7
# ..                                ...        ...        ...        ...
# 119                            Norway          5          x          –
# 120                              Oman        9.6        NaN       84.8
# 121                          Pakistan         32          x       28.8
# 122                             Palau          –        NaN          –
# 123                            Panama         10          x          –
# 124                  Papua New Guinea         11          x          –
# 125                          Paraguay        6.3        NaN       47.1
# 126                              Peru          8          x       51.3
# 127                       Philippines         21        NaN       53.5
# 128                            Poland          6          x          –
# 129                          Portugal          8          x          –
# 130                             Qatar          –        NaN          –
# 131                 Republic of Korea          4          x          –
# 132               Republic of Moldova          6          x       64.5
# 133                           Romania          8          x          –
# 134                Russian Federation          6          x          –
# 135                            Rwanda        7.1        NaN       71.3
# 136             Saint Kitts and Nevis        7.8        NaN          –
# 137                       Saint Lucia       11.4        NaN          –
# 138  Saint Vincent and the Grenadines        7.9        NaN          –
# 139                             Samoa       10.2        NaN       87.6
# 140                        San Marino          –        NaN          –
# 141             Sao Tome and Principe        9.9        NaN       35.3
# 142                      Saudi Arabia          –        NaN          –
# 143                           Senegal       18.6        NaN         48
# 144                            Serbia        6.1        NaN        7.6
# 145                        Seychelles          –        NaN          –
# 146                      Sierra Leone       10.5        NaN       44.6
# 147                         Singapore          8          x          –
# 148                          Slovakia          7          x          –
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0          NaN          –        NaN          –         NaN           –
# 1            x         12          x    83.2918           x        16.2
# 2          NaN          –        NaN          –         NaN           –
# 3          NaN          –        NaN          –         NaN           –
# 4          NaN       64.1        NaN         62         NaN        89.6
# 5          NaN          –        NaN          –         NaN           –
# 6            x          9          x       38.3           x         3.6
# 7          NaN          –        NaN          –         NaN           –
# 8          NaN       14.7        NaN       68.5         NaN        34.9
# 9          NaN       32.5        NaN       76.3           y        92.1
# 10         NaN       48.7        NaN       66.7         NaN        65.7
# 11         NaN       60.4        NaN     82.555         NaN        39.8
# 12         NaN       18.5        NaN       71.3         NaN        12.2
# 13           x         20          x       45.5         x,y         5.9
# 14         NaN         41        NaN       69.9         x,y        25.2
# 15         NaN          –        NaN          –         NaN           –
# 16         NaN          –        NaN          –         NaN           –
# 17         NaN       38.2        NaN       57.4         NaN        80.1
# 18         NaN       69.3        NaN       69.7           y        79.1
# 19           x         60          x         80         x,y        12.7
# 20         NaN       73.5        NaN       87.7         NaN        43.4
# 21           x         20        NaN       63.4           x        24.3
# 22         NaN          –        NaN          –         NaN           –
# 23         NaN       34.3        NaN       59.8         NaN        32.1
# 24         NaN        3.4        NaN       46.1         NaN        59.1
# 25         NaN         63          x          –         NaN           –
# 26         NaN       27.6        NaN       43.3           y           –
# 27           x       42.8        NaN    85.5854         NaN        32.5
# 28           x          –        NaN       34.3         x,y        45.1
# 29           x         19          x       78.1         x,y        21.3
# ..         ...        ...        ...        ...         ...         ...
# 119        NaN          –        NaN          –         NaN           –
# 120          x          –        NaN       91.1         x,y        72.7
# 121          x         37          x       36.3         x,y          55
# 122        NaN          –        NaN          –         NaN           –
# 123        NaN          –        NaN          –         NaN           –
# 124        NaN         56          x       75.9         x,y        71.6
# 125        NaN       24.4        NaN       66.6           y        14.3
# 126        NaN       70.6        NaN    81.7854         NaN        54.9
# 127        NaN         34        NaN     90.138         NaN        34.2
# 128        NaN          –        NaN          –         NaN           –
# 129        NaN          –        NaN          –         NaN           –
# 130        NaN          –        NaN          –         NaN           –
# 131        NaN          –        NaN          –         NaN           –
# 132          x         46          x       17.8         x,y         2.4
# 133        NaN         16          x         41         x,y           –
# 134        NaN          –        NaN          –         NaN           –
# 135        NaN       84.9        NaN       79.1         NaN        83.5
# 136        NaN          –        NaN          –         NaN           –
# 137        NaN          –        NaN          –         NaN           –
# 138        NaN          –        NaN          –         NaN           –
# 139        NaN       51.3        NaN       71.1           y        73.9
# 140        NaN          –        NaN          –         NaN           –
# 141          x       51.4        NaN    73.8564         NaN          20
# 142        NaN          –        NaN          –         NaN           –
# 143        NaN         39        NaN       67.2           y        50.7
# 144        NaN       13.7        NaN       84.1         NaN        15.3
# 145        NaN          –        NaN          –         NaN           –
# 146        NaN       31.6        NaN       25.1         NaN        48.2
# 147        NaN          –        NaN          –         NaN           –
# 148        NaN          –        NaN          –         NaN           –
#
#         ...     Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 0       ...               –         NaN           –         NaN           –
# 1       ...              25           x           7           x        12.9
# 2       ...               –         NaN           –         NaN           –
# 3       ...               –         NaN           –         NaN           –
# 4       ...            41.3         NaN        15.6         NaN         1.5
# 5       ...               –         NaN           –         NaN           –
# 6       ...               4           x           2           x         9.7
# 7       ...               –         NaN           –         NaN           –
# 8       ...            19.3         NaN         3.3         NaN         7.9
# 9       ...            44.6         NaN          16         NaN        17.9
# 10      ...            33.5         NaN         5.9         NaN         7.6
# 11      ...            27.1         NaN         1.4         NaN         8.5
# 12      ...             8.9         NaN         2.3         NaN        17.4
# 13      ...            31.4           x         7.2           x        11.2
# 14      ...               7           x           2           x         7.3
# 15      ...               –         NaN           –         NaN           –
# 16      ...               –         NaN           –         NaN           –
# 17      ...            32.9         NaN        10.9         NaN         2.4
# 18      ...            57.7         NaN         5.8         NaN         2.7
# 19      ...               –         NaN           –         NaN           –
# 20      ...            39.9         NaN        10.9         NaN         1.6
# 21      ...            32.5         NaN         5.6         NaN         6.5
# 22      ...               –         NaN           –         NaN           –
# 23      ...            40.7         NaN         7.4         NaN         1.8
# 24      ...            38.7         NaN        15.7         NaN         2.8
# 25      ...               –         NaN           –         NaN           –
# 26      ...             9.9         NaN         2.3         NaN         6.6
# 27      ...            13.2         NaN         0.9         NaN         4.8
# 28      ...            30.1         NaN        11.1         NaN         9.3
# 29      ...              30           x           8           x         3.3
# ..      ...             ...         ...         ...         ...         ...
# 119     ...               –         NaN           –         NaN           –
# 120     ...             9.8         NaN         7.1         NaN         1.7
# 121     ...            43.7         NaN        15.1         NaN         6.4
# 122     ...               –         NaN           –         NaN           –
# 123     ...              19         NaN           1         NaN           –
# 124     ...            43.6           x           5           x         4.4
# 125     ...            17.5           x         1.1           x         7.1
# 126     ...            19.5         NaN         0.4         NaN         9.8
# 127     ...              32         NaN           7         NaN         4.3
# 128     ...               –         NaN           –         NaN           –
# 129     ...               –         NaN           –         NaN           –
# 130     ...               –         NaN           –         NaN           –
# 131     ...               –         NaN           –         NaN           –
# 132     ...              10           x           5           x         9.1
# 133     ...              13           x           4           x         8.3
# 134     ...               –         NaN           –         NaN           –
# 135     ...            44.2         NaN         2.8         NaN         7.1
# 136     ...               –         NaN           –         NaN           –
# 137     ...               –         NaN           –         NaN           –
# 138     ...               –         NaN           –         NaN           –
# 139     ...               –         NaN           –         NaN           –
# 140     ...               –         NaN           –         NaN           –
# 141     ...            29.3         NaN        10.5         NaN        10.5
# 142     ...               –         NaN           –         NaN           –
# 143     ...            26.5         NaN        10.1         NaN         2.5
# 144     ...             6.6         NaN         3.5         NaN        15.6
# 145     ...               –         NaN           –         NaN           –
# 146     ...            44.4         NaN         8.5         NaN         9.6
# 147     ...             4.4           x         3.6           x         2.6
# 148     ...               –         NaN           –         NaN           –
#
#     Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0           NaN           –         NaN           –         NaN
# 1             x          90           w        53.8           x
# 2           NaN           –         NaN           –         NaN
# 3           NaN           –         NaN           –         NaN
# 4           NaN          99         NaN        82.3           y
# 5           NaN           –         NaN           –         NaN
# 6             x           –         NaN           –         NaN
# 7           NaN           –         NaN           –         NaN
# 8           NaN           –         NaN           –         NaN
# 9           NaN          99         NaN          86         NaN
# 10          NaN          43         NaN        96.2         x,y
# 11          NaN          41         NaN        88.7           y
# 12          NaN           –         NaN          62         x,y
# 13            x           –         NaN        65.2           x
# 14            x           –         NaN        95.7         x,y
# 15          NaN           –         NaN           –         NaN
# 16          NaN           –         NaN         100           x
# 17          NaN          99         NaN        95.9           y
# 18          NaN           –         NaN        96.1           y
# 19          NaN           –         NaN        74.8         NaN
# 20          NaN          98         NaN        82.7           y
# 21          NaN          88         NaN        49.1         x,y
# 22          NaN           –         NaN           –         NaN
# 23          NaN          83         NaN        64.5         NaN
# 24          NaN           0         NaN        53.8         NaN
# 25          NaN           –         NaN           –         NaN
# 26          NaN           –         NaN        96.8           y
# 27          NaN           –         NaN           –         NaN
# 28          NaN           –         NaN        82.3           x
# 29          NaN           –         NaN          82           x
# ..          ...         ...         ...         ...         ...
# 119         NaN           –         NaN           –         NaN
# 120         NaN           –         NaN        68.5         x,y
# 121         NaN          99         NaN        69.1         NaN
# 122         NaN           –         NaN           –         NaN
# 123         NaN           –         NaN           –         NaN
# 124           x          15         NaN        91.9           x
# 125           x           –         NaN        93.4         NaN
# 126         NaN           –         NaN        90.5         NaN
# 127         NaN          90         NaN        44.5           x
# 128         NaN           –         NaN           –         NaN
# 129         NaN           –         NaN           –         NaN
# 130         NaN           –         NaN           –         NaN
# 131         NaN           –         NaN           –         NaN
# 132           x           –         NaN        59.8           x
# 133           x           –         NaN          74           x
# 134         NaN           –         NaN          35         x,y
# 135         NaN           3         NaN        99.3         NaN
# 136         NaN           –         NaN         100         x,y
# 137         NaN           –         NaN           –         NaN
# 138         NaN           –         NaN           –         NaN
# 139         NaN           –         NaN           –         NaN
# 140         NaN           –         NaN           –         NaN
# 141         NaN          34         NaN        85.6         NaN
# 142         NaN           –         NaN           –         NaN
# 143         NaN           –         NaN          47         NaN
# 144         NaN           –         NaN        32.2           x
# 145         NaN           –         NaN           –         NaN
# 146         NaN          99         NaN        62.6         NaN
# 147           x           –         NaN           –         NaN
# 148         NaN           –         NaN           –         NaN
#
# [149 rows x 25 columns]

# %% [markdown]
# ###  Task 2 Set country index
#
#
# So far we have extracted all the records (or rows) for 196 countries in our Excel file.
# Let's set the country names as row indices, and reset the column labels.
#
# Note that all country names are stored in the column "TABLE 2. NUTRITION". You also need to drop the column after indexing.

# %%
# Set the country names as row indices
df = df.set_index(df['TABLE 2. NUTRITION'].values)

# Delete "TABLE 2. NUTRITION" column, it is now redundant.
df = df.drop('TABLE 2. NUTRITION', 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'TABLE 2. NUTRITION'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-aededd47a26e> in <module>()
#       1 # Set the country names as row indices
# ----> 2 df = df.set_index(df['TABLE 2. NUTRITION'].values)
#       3
#       4 # Delete "TABLE 2. NUTRITION" column, it is now redundant.
#       5 df = df.drop('TABLE 2. NUTRITION', 1)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'TABLE 2. NUTRITION'

# %% [markdown]
# We will re index the column names again to make the dataframe easy to work with.

# %%
# Reindex columns
#
df.columns = list(range(len(df.columns))) 
df
# Out:
#                                     0    1     2    3     4    5        6   \
# Austria                              7    x     –  NaN     –  NaN        –
# Azerbaijan                          10    x  31.9    x    12    x  83.2918
# Bahamas                             11    x     –  NaN     –  NaN        –
# Bahrain                              –  NaN     –  NaN     –  NaN        –
# Bangladesh                          22    x  47.1  NaN  64.1  NaN       62
# Barbados                          11.8  NaN     –  NaN     –  NaN        –
# Belarus                              4    x  21.1    x     9    x     38.3
# Belgium                              –  NaN     –  NaN     –  NaN        –
# Belize                            11.1  NaN  61.5  NaN  14.7  NaN     68.5
# Benin                               15    x  50.4  NaN  32.5  NaN     76.3
# Bhutan                             9.9  NaN    59  NaN  48.7  NaN     66.7
# Bolivia (Plurinational State of)     6  NaN  63.8  NaN  60.4  NaN   82.555
# Bosnia and Herzegovina             3.1  NaN  42.3  NaN  18.5  NaN     71.3
# Botswana                            13    x    40    x    20    x     45.5
# Brazil                            8.39  NaN  67.7  NaN    41  NaN     69.9
# Brunei Darussalam                    –  NaN     –  NaN     –  NaN        –
# Bulgaria                           8.8  NaN     –  NaN     –  NaN        –
# Burkina Faso                      14.1  NaN  42.1  NaN  38.2  NaN     57.4
# Burundi                           12.9  NaN  73.6  NaN  69.3  NaN     69.7
# Cabo Verde                           6    x  72.7    x    60    x       80
# Cambodia                          11.3  NaN  65.8  NaN  73.5  NaN     87.7
# Cameroon                            11    x  19.6    x    20  NaN     63.4
# Canada                               6    x     –  NaN     –  NaN        –
# Central African Republic          13.7  NaN  43.5  NaN  34.3  NaN     59.8
# Chad                              19.9  NaN  28.7  NaN   3.4  NaN     46.1
# Chile                              5.9  NaN     –  NaN    63    x        –
# China                                3  NaN    41  NaN  27.6  NaN     43.3
# Colombia                             6    x  48.9    x  42.8  NaN  85.5854
# Comoros                             25    x  24.9    x     –  NaN     34.3
# Congo                               13    x  38.7    x    19    x     78.1
# ...                                ...  ...   ...  ...   ...  ...      ...
# Norway                               5    x     –  NaN     –  NaN        –
# Oman                               9.6  NaN  84.8    x     –  NaN     91.1
# Pakistan                            32    x  28.8    x    37    x     36.3
# Palau                                –  NaN     –  NaN     –  NaN        –
# Panama                              10    x     –  NaN     –  NaN        –
# Papua New Guinea                    11    x     –  NaN    56    x     75.9
# Paraguay                           6.3  NaN  47.1  NaN  24.4  NaN     66.6
# Peru                                 8    x  51.3  NaN  70.6  NaN  81.7854
# Philippines                         21  NaN  53.5  NaN    34  NaN   90.138
# Poland                               6    x     –  NaN     –  NaN        –
# Portugal                             8    x     –  NaN     –  NaN        –
# Qatar                                –  NaN     –  NaN     –  NaN        –
# Republic of Korea                    4    x     –  NaN     –  NaN        –
# Republic of Moldova                  6    x  64.5    x    46    x     17.8
# Romania                              8    x     –  NaN    16    x       41
# Russian Federation                   6    x     –  NaN     –  NaN        –
# Rwanda                             7.1  NaN  71.3  NaN  84.9  NaN     79.1
# Saint Kitts and Nevis              7.8  NaN     –  NaN     –  NaN        –
# Saint Lucia                       11.4  NaN     –  NaN     –  NaN        –
# Saint Vincent and the Grenadines   7.9  NaN     –  NaN     –  NaN        –
# Samoa                             10.2  NaN  87.6  NaN  51.3  NaN     71.1
# San Marino                           –  NaN     –  NaN     –  NaN        –
# Sao Tome and Principe              9.9  NaN  35.3    x  51.4  NaN  73.8564
# Saudi Arabia                         –  NaN     –  NaN     –  NaN        –
# Senegal                           18.6  NaN    48  NaN    39  NaN     67.2
# Serbia                             6.1  NaN   7.6  NaN  13.7  NaN     84.1
# Seychelles                           –  NaN     –  NaN     –  NaN        –
# Sierra Leone                      10.5  NaN  44.6  NaN  31.6  NaN     25.1
# Singapore                            8    x     –  NaN     –  NaN        –
# Slovakia                             7    x     –  NaN     –  NaN        –
#
#                                    7     8    9  ...     14   15    16   17  \
# Austria                           NaN     –  NaN ...      –  NaN     –  NaN
# Azerbaijan                          x  16.2    x ...     25    x     7    x
# Bahamas                           NaN     –  NaN ...      –  NaN     –  NaN
# Bahrain                           NaN     –  NaN ...      –  NaN     –  NaN
# Bangladesh                        NaN  89.6  NaN ...   41.3  NaN  15.6  NaN
# Barbados                          NaN     –  NaN ...      –  NaN     –  NaN
# Belarus                             x   3.6    x ...      4    x     2    x
# Belgium                           NaN     –  NaN ...      –  NaN     –  NaN
# Belize                            NaN  34.9  NaN ...   19.3  NaN   3.3  NaN
# Benin                               y  92.1  NaN ...   44.6  NaN    16  NaN
# Bhutan                            NaN  65.7  NaN ...   33.5  NaN   5.9  NaN
# Bolivia (Plurinational State of)  NaN  39.8  NaN ...   27.1  NaN   1.4  NaN
# Bosnia and Herzegovina            NaN  12.2  NaN ...    8.9  NaN   2.3  NaN
# Botswana                          x,y   5.9    x ...   31.4    x   7.2    x
# Brazil                            x,y  25.2    x ...      7    x     2    x
# Brunei Darussalam                 NaN     –  NaN ...      –  NaN     –  NaN
# Bulgaria                          NaN     –  NaN ...      –  NaN     –  NaN
# Burkina Faso                      NaN  80.1  NaN ...   32.9  NaN  10.9  NaN
# Burundi                             y  79.1  NaN ...   57.7  NaN   5.8  NaN
# Cabo Verde                        x,y  12.7    x ...      –  NaN     –  NaN
# Cambodia                          NaN  43.4  NaN ...   39.9  NaN  10.9  NaN
# Cameroon                            x  24.3  NaN ...   32.5  NaN   5.6  NaN
# Canada                            NaN     –  NaN ...      –  NaN     –  NaN
# Central African Republic          NaN  32.1  NaN ...   40.7  NaN   7.4  NaN
# Chad                              NaN  59.1  NaN ...   38.7  NaN  15.7  NaN
# Chile                             NaN     –  NaN ...      –  NaN     –  NaN
# China                               y     –  NaN ...    9.9  NaN   2.3  NaN
# Colombia                          NaN  32.5  NaN ...   13.2  NaN   0.9  NaN
# Comoros                           x,y  45.1    x ...   30.1  NaN  11.1  NaN
# Congo                             x,y  21.3    x ...     30    x     8    x
# ...                               ...   ...  ... ...    ...  ...   ...  ...
# Norway                            NaN     –  NaN ...      –  NaN     –  NaN
# Oman                              x,y  72.7    x ...    9.8  NaN   7.1  NaN
# Pakistan                          x,y    55    x ...   43.7  NaN  15.1  NaN
# Palau                             NaN     –  NaN ...      –  NaN     –  NaN
# Panama                            NaN     –  NaN ...     19  NaN     1  NaN
# Papua New Guinea                  x,y  71.6    x ...   43.6    x     5    x
# Paraguay                            y  14.3  NaN ...   17.5    x   1.1    x
# Peru                              NaN  54.9  NaN ...   19.5  NaN   0.4  NaN
# Philippines                       NaN  34.2  NaN ...     32  NaN     7  NaN
# Poland                            NaN     –  NaN ...      –  NaN     –  NaN
# Portugal                          NaN     –  NaN ...      –  NaN     –  NaN
# Qatar                             NaN     –  NaN ...      –  NaN     –  NaN
# Republic of Korea                 NaN     –  NaN ...      –  NaN     –  NaN
# Republic of Moldova               x,y   2.4    x ...     10    x     5    x
# Romania                           x,y     –  NaN ...     13    x     4    x
# Russian Federation                NaN     –  NaN ...      –  NaN     –  NaN
# Rwanda                            NaN  83.5  NaN ...   44.2  NaN   2.8  NaN
# Saint Kitts and Nevis             NaN     –  NaN ...      –  NaN     –  NaN
# Saint Lucia                       NaN     –  NaN ...      –  NaN     –  NaN
# Saint Vincent and the Grenadines  NaN     –  NaN ...      –  NaN     –  NaN
# Samoa                               y  73.9  NaN ...      –  NaN     –  NaN
# San Marino                        NaN     –  NaN ...      –  NaN     –  NaN
# Sao Tome and Principe             NaN    20  NaN ...   29.3  NaN  10.5  NaN
# Saudi Arabia                      NaN     –  NaN ...      –  NaN     –  NaN
# Senegal                             y  50.7  NaN ...   26.5  NaN  10.1  NaN
# Serbia                            NaN  15.3  NaN ...    6.6  NaN   3.5  NaN
# Seychelles                        NaN     –  NaN ...      –  NaN     –  NaN
# Sierra Leone                      NaN  48.2  NaN ...   44.4  NaN   8.5  NaN
# Singapore                         NaN     –  NaN ...    4.4    x   3.6    x
# Slovakia                          NaN     –  NaN ...      –  NaN     –  NaN
#
#                                     18   19  20   21    22   23
# Austria                              –  NaN   –  NaN     –  NaN
# Azerbaijan                        12.9    x  90    w  53.8    x
# Bahamas                              –  NaN   –  NaN     –  NaN
# Bahrain                              –  NaN   –  NaN     –  NaN
# Bangladesh                         1.5  NaN  99  NaN  82.3    y
# Barbados                             –  NaN   –  NaN     –  NaN
# Belarus                            9.7    x   –  NaN     –  NaN
# Belgium                              –  NaN   –  NaN     –  NaN
# Belize                             7.9  NaN   –  NaN     –  NaN
# Benin                             17.9  NaN  99  NaN    86  NaN
# Bhutan                             7.6  NaN  43  NaN  96.2  x,y
# Bolivia (Plurinational State of)   8.5  NaN  41  NaN  88.7    y
# Bosnia and Herzegovina            17.4  NaN   –  NaN    62  x,y
# Botswana                          11.2    x   –  NaN  65.2    x
# Brazil                             7.3    x   –  NaN  95.7  x,y
# Brunei Darussalam                    –  NaN   –  NaN     –  NaN
# Bulgaria                             –  NaN   –  NaN   100    x
# Burkina Faso                       2.4  NaN  99  NaN  95.9    y
# Burundi                            2.7  NaN   –  NaN  96.1    y
# Cabo Verde                           –  NaN   –  NaN  74.8  NaN
# Cambodia                           1.6  NaN  98  NaN  82.7    y
# Cameroon                           6.5  NaN  88  NaN  49.1  x,y
# Canada                               –  NaN   –  NaN     –  NaN
# Central African Republic           1.8  NaN  83  NaN  64.5  NaN
# Chad                               2.8  NaN   0  NaN  53.8  NaN
# Chile                                –  NaN   –  NaN     –  NaN
# China                              6.6  NaN   –  NaN  96.8    y
# Colombia                           4.8  NaN   –  NaN     –  NaN
# Comoros                            9.3  NaN   –  NaN  82.3    x
# Congo                              3.3  NaN   –  NaN    82    x
# ...                                ...  ...  ..  ...   ...  ...
# Norway                               –  NaN   –  NaN     –  NaN
# Oman                               1.7  NaN   –  NaN  68.5  x,y
# Pakistan                           6.4  NaN  99  NaN  69.1  NaN
# Palau                                –  NaN   –  NaN     –  NaN
# Panama                               –  NaN   –  NaN     –  NaN
# Papua New Guinea                   4.4    x  15  NaN  91.9    x
# Paraguay                           7.1    x   –  NaN  93.4  NaN
# Peru                               9.8  NaN   –  NaN  90.5  NaN
# Philippines                        4.3  NaN  90  NaN  44.5    x
# Poland                               –  NaN   –  NaN     –  NaN
# Portugal                             –  NaN   –  NaN     –  NaN
# Qatar                                –  NaN   –  NaN     –  NaN
# Republic of Korea                    –  NaN   –  NaN     –  NaN
# Republic of Moldova                9.1    x   –  NaN  59.8    x
# Romania                            8.3    x   –  NaN    74    x
# Russian Federation                   –  NaN   –  NaN    35  x,y
# Rwanda                             7.1  NaN   3  NaN  99.3  NaN
# Saint Kitts and Nevis                –  NaN   –  NaN   100  x,y
# Saint Lucia                          –  NaN   –  NaN     –  NaN
# Saint Vincent and the Grenadines     –  NaN   –  NaN     –  NaN
# Samoa                                –  NaN   –  NaN     –  NaN
# San Marino                           –  NaN   –  NaN     –  NaN
# Sao Tome and Principe             10.5  NaN  34  NaN  85.6  NaN
# Saudi Arabia                         –  NaN   –  NaN     –  NaN
# Senegal                            2.5  NaN   –  NaN    47  NaN
# Serbia                            15.6  NaN   –  NaN  32.2    x
# Seychelles                           –  NaN   –  NaN     –  NaN
# Sierra Leone                       9.6  NaN  99  NaN  62.6  NaN
# Singapore                          2.6    x   –  NaN     –  NaN
# Slovakia                             –  NaN   –  NaN     –  NaN
#
# [149 rows x 24 columns]

# %% [markdown]
# ### Task 3 Tidy up all columns
#
# However, those records are still messy.
# As you can see in the printout, there are a lot of NaNs,
# and cell values with both numbers and letters (e.g., "6 x", " 39 x,y",) spread over two columns.
# Therefore, we need to merge every two columns together.
#
# How can we do that?
#
# Let us have a look at the first 10 rows and 2 columns.

# %%
df.iloc[:10, :2]
#type(df.iloc[0,1])
#type(df.iloc[0,2])
#df.dtypes
# Out:
#                0    1
# Austria        7    x
# Azerbaijan    10    x
# Bahamas       11    x
# Bahrain        –  NaN
# Bangladesh    22    x
# Barbados    11.8  NaN
# Belarus        4    x
# Belgium        –  NaN
# Belize      11.1  NaN
# Benin         15    x

# %% [markdown]
# A close look at the printout will give you the following patterns:
# * If the cell contains only a float or '-', the corresponding cell value in the odd-numbered column is "NaN".
# See the rows labeled "**Afghanistan**``", "**Albania**", etc.
# * If the original cell contains a float and a couple of letters, the cell in the even-numbered column contains the float, and the one in the odd-numbered column contains the letters.
# See the rows labeled "**Algeria**", "**Angola**". etc.
#
# Assume that we are going to merge the two cells containing a float and letters respectively.
# We need a FOR loop iterating over either odd- or even-numbered columns.
# Within this FOR loop, another FOR loop is needed to iterate over rows.
# For each row, we check if the cell in the odd-numbered column contains NaN.
# If it does, we then merge it with the cell in the corresponding even-numbered column on the left.
#
# Have a try now:

# %%
# A FOR loop over odd-numberd columns
for col_idx in range(1, 24, 2): 
    # A For loop over rows
    for row_idx in range(len(df)):
        if not pd.isnull(df.iloc[row_idx, col_idx]):
            df[col_idx-1][row_idx] = str(df[col_idx-1][row_idx]) + ' ' + str(df[col_idx][row_idx])
        #df.drop(col_idx, 1, inplace = True)
df.head()

# %% [markdown]
# The next step is to remove the odd-numbered columns in the data frame, as they are redundant now.
# To do this, we are going to use DataFrame's `drop()` function again as follows

# %%
for col_idx in range(1, 24, 2): 
    df.drop(col_idx, 1, inplace = True)
df.head()
# Out:
#               0       2     4                   6       8     10     12    14  \
# Austria      7 x       –     –                   –       –     –      –     –
# Azerbaijan  10 x  31.9 x  12 x  83.2917648882958 x  16.2 x   8 x  1.8 x  25 x
# Bahamas     11 x       –     –                   –       –     –      –     –
# Bahrain        –       –     –                   –       –     –      –     –
# Bangladesh  22 x    47.1  64.1                  62    89.6  36.4   10.4  41.3
#
#               16      18    20      22
# Austria        –       –     –       –
# Azerbaijan   7 x  12.9 x  90 w  53.8 x
# Bahamas        –       –     –       –
# Bahrain        –       –     –       –
# Bangladesh  15.6     1.5    99  82.3 y

# %% [markdown]
# Now the data is in a pretty good shape aside from the column heads.
# We can reindex all the columns with integers, or you can extract
# the column heads from the Excel file using either manual or programmatic method.
# Here we are going to use integers.

# %%
df.columns = range(len(df.columns))
df.head()
# Out:
#               0       1     2                   3       4     5      6     7   \
# Austria      7 x       –     –                   –       –     –      –     –
# Azerbaijan  10 x  31.9 x  12 x  83.2917648882958 x  16.2 x   8 x  1.8 x  25 x
# Bahamas     11 x       –     –                   –       –     –      –     –
# Bahrain        –       –     –                   –       –     –      –     –
# Bangladesh  22 x    47.1  64.1                  62    89.6  36.4   10.4  41.3
#
#               8       9     10      11
# Austria        –       –     –       –
# Azerbaijan   7 x  12.9 x  90 w  53.8 x
# Bahamas        –       –     –       –
# Bahrain        –       –     –       –
# Bangladesh  15.6     1.5    99  82.3 y

# %% [markdown]
# One more work to do, rename all columns.

# %%
df.columns =["Low birthweight (%)", \
             "Early initiation of breastfeeding (%)", \
             "Exclusive breastfeeding <6 months (%)", \
             "Introduction of solid, semi-solid or soft foods 6–8 months (%)", \
             "Breastfeeding at age 2 (%)", \
             "Underweight (%) moderate and severe", \
             "Underweight (%) severe", \
             "Stunting (%) moderate and severe", \
             "Wasting (%) moderate and severe", \
             "Overweight (%) moderate and severe", \
             "Vitamin A supplementation, full coverage (%)", \
             "Iodized salt consumption (%)" ]
df.head()
# Out:
#            Low birthweight (%) Early initiation of breastfeeding (%)  \
# Austria                    7 x                                     –
# Azerbaijan                10 x                                31.9 x
# Bahamas                   11 x                                     –
# Bahrain                      –                                     –
# Bangladesh                22 x                                  47.1
#
#            Exclusive breastfeeding <6 months (%)  \
# Austria                                        –
# Azerbaijan                                  12 x
# Bahamas                                        –
# Bahrain                                        –
# Bangladesh                                  64.1
#
#            Introduction of solid, semi-solid or soft foods 6–8 months (%)  \
# Austria                                                     –
# Azerbaijan                                 83.2917648882958 x
# Bahamas                                                     –
# Bahrain                                                     –
# Bangladesh                                                 62
#
#            Breastfeeding at age 2 (%) Underweight (%) moderate and severe  \
# Austria                             –                                   –
# Azerbaijan                     16.2 x                                 8 x
# Bahamas                             –                                   –
# Bahrain                             –                                   –
# Bangladesh                       89.6                                36.4
#
#            Underweight (%) severe Stunting (%) moderate and severe  \
# Austria                         –                                –
# Azerbaijan                  1.8 x                             25 x
# Bahamas                         –                                –
# Bahrain                         –                                –
# Bangladesh                   10.4                             41.3
#
#            Wasting (%) moderate and severe Overweight (%) moderate and severe  \
# Austria                                  –                                  –
# Azerbaijan                             7 x                             12.9 x
# Bahamas                                  –                                  –
# Bahrain                                  –                                  –
# Bangladesh                            15.6                                1.5
#
#            Vitamin A supplementation, full coverage (%)  \
# Austria                                               –
# Azerbaijan                                         90 w
# Bahamas                                               –
# Bahrain                                               –
# Bangladesh                                           99
#
#            Iodized salt consumption (%)
# Austria                               –
# Azerbaijan                       53.8 x
# Bahamas                               –
# Bahrain                               –
# Bangladesh                       82.3 y

# %% [markdown]
# Finally, we have extracted the data table from our Excel file, and put it into a Pandas DataFrame.
# The DataFrame has 197 rows and 12 columns, where rows correspond to records for individual countries
# and columns are variables (or attributes).
# Our last step is to save the data table in a CSV file.

# %%
df.to_csv('en_final_table_2.csv')

# %% [markdown]
# What is the problem you get? Let's check the type of some values in the DataFrame using
# ```
#     type(df.iloc[i,j])
# ```
# where i indicates row index, and j indicates column index.
# You will find that DataFrame's `read_excel` method has parsed all strings and special characters,
# like '-', into Unicode objects.
# If you print the DataFrame, however, you'll get the printed version of the Unicode.
# In contrast, printing a value in a specific location, for example,
# ```python
#     df.iloc[0,0]
# ```
# gives you the original Unicode,
# ```
#     u'\u2013'
# ```
# Therefore, you need to specify the encoding method while saving
# the DataFrame into a CSV file.

# %%
df.to_csv('./en_final_table_2.csv', sep='\t', encoding='utf-32')

# %% [markdown]
# ## 3. Summary
# Compared with the three formats discussed previously,
# Excel files are not meant to be read by programming languages, but they can still be parsed with a bit more effort.
# In this tutorial, you have learnt how to extract data from an Excel file and save
# the extracted data in a CSV file using Pandas ExcelFile class and various
# methods for manipulating DataFrame.
#
# ## 4. Exercise
# 1. In the introduction, we have mentioned a couple of Python libraries that can be
# use to manipulate Excel files. Here we suggest that you download and install `openpyxl`,
# and try to write your own Python script to parse the same Excel file, and store the data in the
# same format as in Section 2.
