# %%
import pandas as pd

df = pd.read_csv("29286875.csv")
# print(df1)
# Out:
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# change the column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
df.head(n=3)
# Out:
#              id  drone_type  post_type  package_weight  origin_region  \
# 0  ID5174772222         2.0        1.0          43.632           47.0
# 1  ID1302741470         2.0        0.0          14.230           42.0
# 2  ID1271333154         1.0        0.0          31.700           19.0
#
#    destination_region  origin_latitude  origin_longitude  \
# 0                 3.0       -37.355446        145.140356
# 1                45.0       -38.029425        146.072856
# 2                 8.0       -38.467031        144.056414
#
#    destination_latitude  destination_longitude  journey_distance  \
# 0            -36.683571             147.271147           203.610
# 1            -38.880642             145.089798           127.756
# 2            -37.882256             147.344381           294.983
#
#   departure_date departure_time  travel_time delivery_time  delivery_fare
# 0     2018-03-24       03:47:54       163.99       6:31:53         187.16
# 1     2018-04-01       19:00:04       105.65      20:45:43         132.04
# 2     2018-04-27       01:05:05       240.38       5:05:27         122.90

# %%
speed_df = pd.DataFrame(df[['drone_type', 'journey_distance', 'travel_time']], columns=['drone_type', 'journey_distance', 'travel_time'])
speed_df
# Out:
#        drone_type  journey_distance  travel_time
# 0             2.0           203.610       163.99
# 1             2.0           127.756       105.65
# 2             1.0           294.983       240.38
# 3             2.0           169.915       138.08
# 4             1.0            61.595        56.13
# 5             2.0           253.963       202.73
# 6             3.0           176.649       141.38
# 7             1.0           289.890       236.36
# 8             1.0           281.808       229.98
# 9             1.0           267.079       218.35
# 10            3.0           352.587       275.00
# 11            3.0           267.656       210.50
# 12            1.0           272.028       222.26
# 13            3.0           250.305       197.32
# 14            2.0           466.072       365.89
# 15            1.0           371.170       300.53
# 16            2.0           229.061       183.57
# 17            1.0            97.011        84.09
# 18            3.0           237.317       187.46
# 19            1.0            80.749        71.25
# 20            1.0           197.489       163.41
# 21            2.0           190.436       153.86
# 22            3.0           353.345       275.58
# 23            1.0           158.435       132.58
# 24            1.0           199.985       165.38
# 25            1.0           153.102       128.37
# 26            1.0           231.398       190.18
# 27            3.0           423.036       328.51
# 28            3.0           198.020       157.61
# 29            1.0            92.192        80.28
# ...           ...               ...          ...
# 39083         2.0           255.414       203.84
# 39084         2.0            43.185        40.59
# 39085         2.0           220.716       177.15
# 39086         3.0             8.773        13.88
# 39087         1.0           192.335       159.34
# 39088         2.0           297.363       236.11
# 39089         2.0           328.951       260.41
# 39090         2.0           444.416       349.23
# 39091         1.0           278.102       227.05
# 39092         1.0           162.252       135.59
# 39093         2.0           101.135        85.17
# 39094         1.0           256.798       210.23
# 39095         1.0           335.683       272.51
# 39096         1.0            98.697        85.42
# 39097         3.0           125.158       102.27
# 39098         1.0           190.789       158.12
# 39099         2.0           184.296       149.14
# 39100         1.0           259.907       212.69
# 39101         2.0           241.325       193.01
# 39102         3.0           244.181       192.67
# 39103         2.0           202.442       163.10
# 39104         1.0            96.946        84.04
# 39105         1.0           450.245       362.96
# 39106         1.0           247.893       203.20
# 39107         1.0           278.652       227.49
# 39108         2.0            85.312        73.00
# 39109         2.0            99.773        84.12
# 39110         3.0           142.088       115.13
# 39111         1.0           297.660       242.49
# 39112         3.0           209.590       166.40
#
# [39113 rows x 3 columns]

# %%
import numpy as np

# the function for calculating speed (distance/time)
def cal_speed(row):
    speed = row['journey_distance']/row['travel_time']
    return speed


# axis=1 or ‘columns’: apply function to each row.
speed_series = speed_df.apply(cal_speed, axis=1)

# add the result of calculation into data frame named 'cal_result'
speed_df['speed'] = pd.Series(speed_series, index=speed_df.index)

# # find which journey_distance is different from cal_result
# post_fare_df['comparison'] = np.where((dist_df['journey_distance'] == dist_df['cal_result']), 'same', 'diff')
speed_df
# Out:
#        drone_type  journey_distance  travel_time     speed
# 0             2.0           203.610       163.99  1.241600
# 1             2.0           127.756       105.65  1.209238
# 2             1.0           294.983       240.38  1.227153
# 3             2.0           169.915       138.08  1.230555
# 4             1.0            61.595        56.13  1.097363
# 5             2.0           253.963       202.73  1.252715
# 6             3.0           176.649       141.38  1.249462
# 7             1.0           289.890       236.36  1.226477
# 8             1.0           281.808       229.98  1.225359
# 9             1.0           267.079       218.35  1.223169
# 10            3.0           352.587       275.00  1.282135
# 11            3.0           267.656       210.50  1.271525
# 12            1.0           272.028       222.26  1.223918
# 13            3.0           250.305       197.32  1.268523
# 14            2.0           466.072       365.89  1.273804
# 15            1.0           371.170       300.53  1.235051
# 16            2.0           229.061       183.57  1.247813
# 17            1.0            97.011        84.09  1.153657
# 18            3.0           237.317       187.46  1.265961
# 19            1.0            80.749        71.25  1.133319
# 20            1.0           197.489       163.41  1.208549
# 21            2.0           190.436       153.86  1.237723
# 22            3.0           353.345       275.58  1.282187
# 23            1.0           158.435       132.58  1.195014
# 24            1.0           199.985       165.38  1.209245
# 25            1.0           153.102       128.37  1.192662
# 26            1.0           231.398       190.18  1.216732
# 27            3.0           423.036       328.51  1.287742
# 28            3.0           198.020       157.61  1.256392
# 29            1.0            92.192        80.28  1.148381
# ...           ...               ...          ...       ...
# 39083         2.0           255.414       203.84  1.253012
# 39084         2.0            43.185        40.59  1.063932
# 39085         2.0           220.716       177.15  1.245927
# 39086         3.0             8.773        13.88  0.632061
# 39087         1.0           192.335       159.34  1.207073
# 39088         2.0           297.363       236.11  1.259426
# 39089         2.0           328.951       260.41  1.263204
# 39090         2.0           444.416       349.23  1.272560
# 39091         1.0           278.102       227.05  1.224849
# 39092         1.0           162.252       135.59  1.196637
# 39093         2.0           101.135        85.17  1.187449
# 39094         1.0           256.798       210.23  1.221510
# 39095         1.0           335.683       272.51  1.231819
# 39096         1.0            98.697        85.42  1.155432
# 39097         3.0           125.158       102.27  1.223800
# 39098         1.0           190.789       158.12  1.206609
# 39099         2.0           184.296       149.14  1.235725
# 39100         1.0           259.907       212.69  1.221999
# 39101         2.0           241.325       193.01  1.250324
# 39102         3.0           244.181       192.67  1.267354
# 39103         2.0           202.442       163.10  1.241214
# 39104         1.0            96.946        84.04  1.153570
# 39105         1.0           450.245       362.96  1.240481
# 39106         1.0           247.893       203.20  1.219946
# 39107         1.0           278.652       227.49  1.224898
# 39108         2.0            85.312        73.00  1.168658
# 39109         2.0            99.773        84.12  1.186079
# 39110         3.0           142.088       115.13  1.234153
# 39111         1.0           297.660       242.49  1.227515
# 39112         3.0           209.590       166.40  1.259555
#
# [39113 rows x 4 columns]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline # 'magic line' to make sure that graphs are shown inline in the notebook
# Out:
# UsageError: unrecognized arguments: # 'magic line' to make sure that graphs are shown inline in the notebook

# %%
# histogram groupby drone type
# Series.nunique(dropna=True): Return number of unique elements in the object.
speed_df.groupby('drone_type')['speed'].nunique().plot(kind='bar')
plt.show()

# find that type1 is the fastest one; 2 is the second fast; 3 is slowest

# %%
# linear groupby drone type
speed_df.groupby('drone_type')['speed'].nunique().plot(kind='line')
plt.show()

# %%
# type(speed_df.groupby('drone_type')['speed'])
# Out:
# pandas.core.groupby.SeriesGroupBy

# %%
speed_df.isnull().sum()
# Out:
# drone_type          10
# journey_distance     0
# travel_time         40
# speed               40
# dtype: int64
