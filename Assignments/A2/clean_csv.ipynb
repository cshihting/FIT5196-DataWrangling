# %%
import pandas as pd


# read csv file
df = pd.read_csv("clean_29286875.csv")
df
# Out:
#        Unnamed: 0            Id  Drone Type  Post Type  Package Weight  \
# 0               0  ID5174772222         2.0        1.0          43.632
# 1               1  ID1302741470         2.0        0.0          14.230
# 2               2  ID1271333154         1.0        0.0          31.700
# 3               3  ID5399258418         2.0        1.0          11.500
# 4               4  ID5288620287         1.0        1.0          14.545
# 5               5  ID5993957587         2.0        1.0          33.332
# 6               6  ID1175666777         3.0        0.0          14.360
# 7               7  ID1247377835         1.0        0.0          16.681
# 8               8  ID1727276208         1.0        0.0           7.631
# 9               9  ID1656980587         1.0        0.0          41.862
# 10             10  ID1229281063         3.0        0.0          36.585
# 11             11  ID1430032672         3.0        0.0          44.666
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Id                       0
# Drone Type               0
# Post Type                0
# Package Weight           0
# Origin Region            0
# Destination Region       0
# Origin Latitude          0
# Origin Longitude         0
# Destination Latitude     0
# Destination Longitude    0
# Journey Distance         0
# Departure Date           0
# Departure Time           0
# Travel Time              0
# Delivery Time            0
# Delivery Fare            0
# dtype: int64
