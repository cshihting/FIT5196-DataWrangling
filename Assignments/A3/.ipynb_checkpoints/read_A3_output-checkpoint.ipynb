# %%
import pandas as pd
# Out:
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
ass3_df = pd.read_csv('29286875.csv', sep=',', index_col=0)
sampl_df = pd.read_csv('sample.csv', sep=',', index_col=0)

# %%
ass3_df
# Out:
#       property_id        lat         lng             addr_street      suburb  \
# 0              74 -37.823833  144.964249  193/38 Kavanagh Street   SOUTHBANK
# 1              76 -37.829295  144.968233      70 Coventry Street   SOUTHBANK
# 2              99 -37.809376  144.888260        1 Chapman Street      SEDDON
# 3             113 -37.806162  144.893858          1 North Street      SEDDON
# 4             135 -37.787984  144.890538       1/5 Gordon Street   FOOTSCRAY
# 5             231 -37.804829  144.890213      110 Pilgrim Street      SEDDON
# 6             357 -37.800015  144.891067        141 Geelong Road   FOOTSCRAY
# 7             414 -37.796816  144.888870       167 Gordon Street   FOOTSCRAY
# 8             494 -37.797726  144.896197       19 Fitzroy Street   FOOTSCRAY
# 9             540 -37.805149  144.888868          2 James Street      SEDDON
# 10            554 -37.790646  144.890808       2/1 Empire Street   FOOTSCRAY
# ...

# %%
print(type(sampl_df.loc[0, 'property_id']))
print(type(ass3_df.loc[0, 'property_id']))

print(type(sampl_df.loc[0, 'lat']))
print(type(ass3_df.loc[0, 'lat']))

print(type(sampl_df.loc[0, 'lng']))
print(type(ass3_df.loc[0, 'lng']))

print(type(sampl_df.loc[0, 'addr_street']))
print(type(ass3_df.loc[0, 'addr_street']))

print(type(sampl_df.loc[0, 'suburb']))
print(type(ass3_df.loc[0, 'suburb']))

print(type(sampl_df.loc[0, 'price']))
print(type(ass3_df.loc[0, 'price']))

print(type(sampl_df.loc[0, 'property_type']))
print(type(ass3_df.loc[0, 'property_type']))

print(type(sampl_df.loc[0, 'year']))
print(type(ass3_df.loc[0, 'year']))

print(type(sampl_df.loc[0, 'bedrooms']))
print(type(ass3_df.loc[0, 'bedrooms']))

print(type(sampl_df.loc[0, 'bathrooms']))
print(type(ass3_df.loc[0, 'bathrooms']))

print(type(sampl_df.loc[0, 'parking_space']))
print(type(ass3_df.loc[0, 'parking_space']))

print(type(sampl_df.loc[0, 'shopping_center_id']))
print(type(ass3_df.loc[0, 'shopping_center_id']))

print(type(sampl_df.loc[0, 'distance_to_sc']))
print(type(ass3_df.loc[0, 'distance_to_sc']))

print(type(sampl_df.loc[0, 'train_station_id']))
print(type(ass3_df.loc[0, 'train_station_id']))

print(type(sampl_df.loc[0, 'distance_to_train_station']))
print(type(ass3_df.loc[0, 'distance_to_train_station']))

print(type(sampl_df.loc[0, 'travel_min_to_CBD']))
print(type(ass3_df.loc[0, 'travel_min_to_CBD']))

print(type(sampl_df.loc[0, 'transfer_flag']))
print(type(ass3_df.loc[0, 'transfer_flag']))

print(type(sampl_df.loc[0, 'hospital_id']))
print(type(ass3_df.loc[0, 'hospital_id']))

print(type(sampl_df.loc[0, 'distance_to_hospital']))
print(type(ass3_df.loc[0, 'distance_to_hospital']))

print(type(sampl_df.loc[0, 'supermarket_id']))
print(type(ass3_df.loc[0, 'supermarket_id']))

print(type(sampl_df.loc[0, 'distance_to_supermaket']))
print(type(ass3_df.loc[0, 'distance_to_supermaket']))
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
