# %% [markdown]
# ##### Only read the filename in a dir

# %%
# use glob:
import glob, os
os.chdir("/Users/eileen/Jupyter/5196 data wrangling/Assignments/A1/PDF/resumeTxt")
for file in glob.glob("*.txt"):
    if file in myDataset_ls:
    print(file)
    
# simply use os.listdir:
import os
for file in os.listdir("/Users/eileen/Jupyter/5196 data wrangling/Assignments/A1/PDF/resumeTxt"):
    if file.endswith(".txt"):
        print(os.path.join(file))
        
# traverse directory, use os.walk:
import os
for root, dirs, files in os.walk("/Users/eileen/Jupyter/5196 data wrangling/Assignments/A1/PDF/resumeTxt"):
    for file in files:
        if file.endswith(".txt"):
             print(os.path.join(root, file))

# %% [markdown]
# ##### Get my selected files (just filenames but contents)

# %%
# 把我的指定履歷編號變成list
myDataset = '262 76 778 565 6 623 200 742 645 418 520 814 467 680 216 12 762 63 \
276 66 236 722 82 779 626 206 276 649 750 20 167 738 602 6 251 808 \
729 115 80 71 539 38 426 44 556 779 251 760 61 728 251 268 421 750 \
832 807 55 452 683 303 560 555 547 265 649 441 633 108 517 744 137 \
446 182 397 442 8 266 630 857 17 498 32 293 711 413 445 392 606 322 \
422 54 582 657 239 309 382 286 105 336 786 788 712 738 516 29 523 \
51 428 43 47 819 649 598 297 615 208 865 720 122 789 372 860 813 \
219 700 275 4 466 455 277 427 728 71 812 284 646 327 397 262 22 \
450 80 377 26 332 45 325 24 274 153 847 311 168 99 361 362 139 602 \
551 517 111 812 1 364 467 323 398 207 837 716 733 685 498 817 336 \
395 154 265 492 117 389 833 705 703 270 218 435 475 338 513 621 \
208 839 560 370 81 445 89 12 645 336 157 47 91 32 797 837 803 195 \
861 237 31 810 634 211 246 278 788 556 726 684 815 460 596 237 640 \
764 251 304 474 154 384 743 749 593 327 749 515 543 310 833 464 724 \
66 331 649 397 426 383 492'
# print(myDataset)

myDataset_ls = []
myDataset_ls = myDataset.split(' ') # 取得指定CV的編號
cv_name_ls = ['resume_(' + s + ').txt' for s in myDataset_ls] # 取得指定CV的全名
# print(myDataset_ls)
# print(cv_name_ls)

# %% [markdown]
# ##### Write all selected files to a new one

# %%
# 先test幾個CVs，把他們先存成一個檔
import os
my_CVs = ''
for file in os.listdir("/Users/eileen/Jupyter/5196 data wrangling/Assignments/A1/PDF"):
    if file in cv_name_ls:
        with open(file, 'r') as f:
            for line in f.readlines():
#                 line = line.strip()
                my_CVs += line
#             my_CVs += '\n*****'
#             print(my_CVs, '\n================'*2)

# to remove whitespace and join into a string
clean_string = ' '.join(my_CVs.split())
# clean_string

# write into a file
f = open('some_cv.txt','a+')
f.write(my_CVs)
f.close()

# %% [markdown]
# ##### * The word tokenization must use the following regular expression,  "\w+(?:[-']\w+)?"
# 抓字

# %%
import re # library for regular expression

# # to remove whitespace and join into a string
# clean_string = ' '.join(my_CVs.split())

# set regex for each token
token = r"\w+(?:[-']\w+)?"

# to find the matched token in clean_string
match_token = re.findall(token, clean_string)
print(match_token)
# Out:
# ['WAN', 'Kin', 'Keung', 'Ken', 'Mobile', '852', '6748-8526', 'Email', 'kinkeung0531', 'gmail', 'com', 'PERSONAL', 'SUMMARY', '4', 'years', 'working', 'experience', 'half', 'year', 'in', 'CPA', 'firm', 'and', '3', '5', 'years', 'fund', 'operation', 'experiences', 'in', 'AIA', '2', 'years', 'supervising', 'experiences', 'Involved', 'in', 'due', 'auditing', 'engagements', 'in', 'logistics', 'industry', 'trading', 'and', 'manufacturing', 'industries', 'and', 'consultation', 'services', 'company', 'Experiences', 'in', 'fund', 'operation', 'valuation', 'regulatory', 'reporting', 'and', 'financial', 'analysis', 'Knowledge', 'for', 'internal', 'controls', 'and', 'risk', 'monitoring', 'WORK', 'EXPERIENCE', 'Mar', '2016', 'Present', 'Senior', 'Associate', 'Accounting', 'and', 'Finance', 'AIA', 'Support', 'the', 'daily', 'operation', 'valuation', 'processes', 'and', 'fund', 'daily', 'monitoring', 'Support', 'the', 'regulatory', 'reporting', 'to', 'MPFA', 'Analyze', 'results', 'and', 'monitoring', 'performance', 'metrics', 'against', 'benchmark', 'forecast', 'and', 'historical', 'trends', 'Support', 'the', 'budgeting', 'for', 'funds', 'operation', 'Liaise', 'and', 'cooperate', 'with', 'internal', 'departments', 'risk', 'and', 'compliance', 'products', 'sales', 'agency', 'customer', 'services', 'external', 'auditors', 'MPFA', 'SFC', 'investment', 'managers', 'etc', 'Review', 'and', 'restructure', 'the', 'working', 'procedures', 'to', 'improve', 'the', 'operation', 'efficiency', 'Support', 'firm', 'wide', 'and', 'departmental', 'projects', 'such', 'as', 'new', 'product', 'launch', 'scheme', 'merger', 'streamline', 'workflow', 'processes', 'within', 'the', 'BU', 'etc', 'Associate', 'Accounting', 'and', 'Finance', 'AIA', 'Support', 'fund', 'valuation', 'team', 'to', 'perform', 'daily', 'fund', 'operation', 'and', 'valuation', 'processes', 'Analyzing', 'operations', 'and', 'fund', 'performance', 'results', 'monitoring', 'variances', 'Conducting', 'analytical', 'reviews', 'on', 'financial', 'transaction', 'to', 'identify', 'unusual', 'price', 'fluctuations', 'Assessing', 'the', 'internal', 'control', 'procedure', 'and', 'compliance', 'requirements', 'Reviewing', 'the', 'appropriateness', 'and', 'completeness', 'of', 'financial', 'statements', 'and', 'accounts', 'disclosures', 'under', 'HKFRS', 'Liaise', 'and', 'cooperate', 'with', 'external', 'auditors', 'compliance', 'departments', 'SFC', 'and', 'MPFA', 'Assist', 'Manager', 'for', 'special', 'projects', 'team', 'for', 'project', 'planning', 'analysis', 'system', 'transformation', 'and', 'UAT', 'Jan', '2014', 'Feb', '2016', 'Aug', '2013', 'Dec', '2013', 'Auditor', 'Cheer', 'Link', 'CPA', 'Limited', 'Assignment', 'to', 'audit', 'engagements', 'for', 'clients', 'with', 'different', 'natures', 'and', 'sizes', 'of', 'business', 'Conducting', 'analytical', 'reviews', 'on', 'financial', 'statements', 'and', 'to', 'identify', 'unusual', 'fluctuations', 'and', 'potential', 'risk', 'exposure', 'Reviewing', 'the', 'appropriateness', 'and', 'completeness', 'of', 'financial', 'statements', 'and', 'accounts', 'disclosures', 'under', 'HKFRS', 'Solid', 'understanding', 'of', 'accounting', 'process', 'by', 'performing', 'walkthrough', 'and', 'validating', 'the', 'relevant', 'control', 'procedures', 'Assessing', 'the', 'fair', 'values', 'on', 'private', 'equities', 'and', 'other', 'financial', 'derivatives', 'with', 'various', 'valuation', 'methodology', 'Conducting', 'sensitivity', 'analysis', 'to', 'evaluate', 'market', 'price', 'risk', 'interest', 'rate', 'risk', 'credit', 'risk', 'and', 'liquidity', 'risk', 'Collaborating', 'with', 'tax', 'department', 'on', 'corporate', 'tax', 'issues', 'EDUCATION', 'City', 'University', 'of', 'Hong', 'Kong', 'Aug', '2010', 'Jul', '2013', 'Bachelor', 'of', 'Business', 'Administration', 'Honours', 'in', 'Accountancy', 'and', 'Management', 'Information', 'Systems', 'Tin', 'Shui', 'Wai', 'Government', 'Secondary', 'School', 'Sept', '2003', 'Jun', '2010', 'EXTRA-CURRICULAR', ' ...

# %%
# better method
import re
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r"\w+(?:[-']\w+)?")
tokens = tokenizer.tokenize(clean_string)
tokens
# Out:
# ['WAN',
#  'Kin',
#  'Keung',
#  'Ken',
#  'Mobile',
#  '852',
#  '6748-8526',
#  'Email',
#  'kinkeung0531',
#  'gmail',
#  'com',
#  'PERSONAL',
#  'SUMMARY',
#  '4',
#  'years',
#  'working',
#  'experience',
#  'half',
#  'year',
#  'in',
#  'CPA',
#  'firm',
#  'and',
#  '3',
#  '5',
#  'years',
#  'fund',
#  'operation',
#  'experiences',
#  'in',
#  'AIA',
#  '2',
#  'years',
#  'supervising',
#  'experiences',
#  'Involved',
#  'in',
#  'due',
#  'auditing',
#  'engagements',
#  'in',
#  'logistics',
#  'industry',
#  'trading',
#  'and',
#  'manufacturing',
#  'industries',
#  'and',
#  'consultation',
#  'services',
#  'company',
#  'Experiences',
#  'in',
#  'fund',
#  'operation',
#  'valuation',
#  'regulatory',
#  'reporting',
#  'and',
#  'financial',
#  'analysis',
#  'Knowledge',
#  'for',
#  'internal',
#  'controls',
#  'and',
#  'risk',
#  'monitoring',
#  'WORK',
#  'EXPERIENCE',
#  'Mar',
#  '2016',
#  'Present',
#  'Senior',
#  'Associate',
#  'Accounting',
#  'and',
#  'Finance',
#  'AIA',
#  'Support',
#  'the',
#  'daily',
#  'operation',
#  'valuation',
#  'processes',
#  'and',
#  'fund',
#  'daily',
#  'monitoring',
#  'Support',
#  'the',
#  'regulatory',
#  'reporting',
#  'to',
#  'MPFA',
#  'Analyze',
#  'results',
#  'and',
#  'monitoring',
#  'performance',
#  'metrics',
#  'against',
#  'benchmark',
#  'forecast',
#  'and',
#  'historical',
#  'trends',
#  'Support',
#  'the',
#  'budgeting',
#  'for',
#  'funds',
#  'operation',
#  'Liaise',
#  'and',
#  'cooperate',
#  'with',
#  'internal',
#  'departments',
#  'risk',
#  'and',
#  'compliance',
#  'products',
#  'sales',
#  'agency',
#  'customer',
#  'services',
#  'external',
#  'auditors',
#  'MPFA',
#  'SFC',
#  'investment',
#  'managers',
#  'etc',
#  'Review',
#  'and',
#  'restructure',
#  'the',
#  'working',
#  'procedures',
#  'to',
#  'improve',
#  'the',
#  'operation',
#  'efficiency',
#  'Support',
#  'firm',
#  'wide',
#  'and',
#  'departmental',
#  'projects',
#  'such',
#  'as',
#  'new',
#  'product',
#  'launch',
#  'scheme',
#  'merger',
#  'streamline',
#  'workflow',
#  'processes',
#  'within',
#  'the',
#  'BU',
#  'etc',
#  'Associate',
#  'Accounting',
#  'and',
#  'Finance',
#  'AIA',
#  'Support',
#  'fund',
#  'valuation',
#  'team',
#  'to',
#  'perform',
#  'daily',
#  'fund',
#  'operation',
#  'and',
#  'valuation',
#  'processes',
#  'Analyzing',
#  'operations',
#  'and',
#  'fund',
#  'performance',
#  'results',
#  'monitoring',
#  'variances',
#  'Conducting',
#  'analytical',
#  'reviews',
#  'on',
#  'financial',
#  'transaction',
#  'to',
#  'identify',
#  'unusual',
#  'price',
#  'fluctuations',
#  'Assessing',
#  'the',
#  'internal',
#  'control',
#  'procedure',
#  'and',
#  'compliance',
#  'requirements',
#  'Reviewing',
#  'the',
#  'appropriateness',
#  'and',
#  'completeness',
#  'of',
#  'financial',
#  'statements',
#  'and',
#  'accounts',
#  'disclosures',
#  'under',
#  'HKFRS',
#  'Liaise',
#  'and',
#  'cooperate',
#  'with',
#  'external',
#  'auditors',
#  'compliance',
#  'departments',
#  'SFC',
#  'and',
#  'MPFA',
#  'Assist',
#  'Manager',
#  'for',
#  'special',
#  'projects',
#  'team',
#  'for',
#  'project',
#  'planning',
#  'analysis',
#  'system',
#  'transformation',
#  'and',
#  'UAT',
#  'Jan',
#  '2014',
#  'Feb',
#  '2016',
#  'Aug',
#  '2013',
#  'Dec',
#  '2013',
#  'Auditor',
#  'Cheer',
#  'Link',
#  'CPA',
#  'Limited',
#  'Assignment',
#  'to',
#  'audit',
#  'engagements',
#  'for',
#  'clients',
#  'with',
#  'different',
#  'natures',
#  'and',
#  'sizes',
#  'of',
#  'business',
#  'Conducting',
#  'analytical',
#  'reviews',
#  'on',
#  'financial',
#  'statements',
#  'and',
#  'to',
#  'identify',
#  'unusual',
#  'fluctuations',
#  'and',
#  'potential',
#  'risk',
#  'exposure',
#  'Reviewing',
#  'the',
#  'appropriateness',
#  'and',
#  'completeness',
#  'of',
#  'financial',
#  'statements',
#  'and',
#  'accounts',
#  'disclosures',
#  'under',
#  'HKFRS',
#  'Solid',
#  'understanding',
#  'of',
#  'accounting',
#  'process',
#  'by',
#  'performing',
#  'walkthrough',
#  'and',
#  'validating',
#  'the',
#  'relevant',
#  'control',
#  'procedures',
#  'Assessing',
#  'the',
#  'fair',
#  'values',
#  'on',
#  'private',
#  'equities',
#  'and',
#  'other',
#  'financial',
#  'derivatives',
#  'with',
#  'various',
#  'valuation',
#  'methodology',
#  'Conducting',
#  'sensitivity',
#  'analysis',
#  'to',
#  'evaluate',
#  'market',
#  'price',
#  'risk',
#  'interest',
#  'rate',
#  'risk',
#  'credit',
#  'risk',
#  'and',
#  'liquidity',
#  'risk',
#  'Collaborating',
#  'with',
#  'tax',
#  'department',
#  'on',
#  'corporate',
#  'tax',
#  'issues',
#  'EDUCATION',
#  'City',
#  'University',
#  'of',
#  'Hong',
#  'Kong',
#  'Aug',
#  '2010',
#  'Jul',
#  '2013',
#  'Bachelor',
#  'of',
#  'Business',
#  'Administration',
#  'Honours',
#  'in',
#  'Accountancy',
#  'and',
#  'Management',
#  'Information',
#  'Systems',
#  'Tin',
#  'Shui',
#  'Wai',
#  'Government',
#  'Secondary',
#  'School',
#  'Sept',
#  '2003',
#  'Jun',
#  '2010',
#  'EXTRA-CURRICULAR',
#  'ACTIVITIES',
#  '2012',
#  '13',
#  '2011',
#  '12',
#  '2010',
#  '11',
#  'Chairperson',
#  'Election',
#  'Board',
#  'of',
#  'HSBC',
#  'Prosperity',
#  'Hall',
#  'Chairperson',
#  'Residents',
#  'Association',
#  'Council',
#  'President',
#  'Residents',
#  'Association',
#  'Executive',
#  'Committee',
#  'PROFESSIONAL',
#  'QUALIFICATIONS',
#  '07',
#  '2010',
#  'Present',
#  'Student',
#  'Member',
#  'of',
#  'Hong',
#  'Kong',
#  'Institute',
#  'of',
#  'Certified',
#  'Public',
#  'Accountants',
#  'SPECIAL',
#  'SKILLS',
#  'Languages',
#  'Fluent',
#  'English',
#  'written',
#  'spoken',
#  'Native',
#  'Chinese',
#  'written',
#  'spoken',
#  'Fluent',
#  'Putonghua',
#  'Strengths',
#  'Strong',
#  'interpersonal',
#  'skill',
#  'and',
#  'communication',
#  'skill',
#  'quick',
#  'learner',
#  'and',
#  'highly',
#  'adaptable',
#  'to',
#  'change',
#  'strong',
#  'analytical',
#  'skills',
#  'and',
#  'problem',
#  'solving',
#  'skill',
#  'Others',
#  'Advanced',
#  'MS',
#  'Office',
#  'Excel',
#  'Word',
#  'PowerPoint',
#  'Access',
#  'Chinese',
#  'English',
#  'word',
#  'processing',
#  'CURRENT',
#  'SALARY',
#  'HK',
#  '22',
#  '000',
#  'per',
#  'month',
#  'included',
#  'allowance',
#  'EXPECTED',
#  'SALARY',
#  'HK',
#  '26',
#  '000',
#  'per',
#  'month',
#  'AVAILABILITY',
#  '1-month',
#  'notice',
#  'YANG',
#  'TAMMIE',
#  'QI',
#  '杨',
#  '琪',
#  'Email',
#  'qyangaf',
#  'gmail',
#  'com',
#  'Mobile',
#  '852',
#  '6020',
#  '4161',
#  'HILIGHTS',
#  'Completed',
#  'ACCA',
#  'professional',
#  'examinations',
#  'Mater',
#  'degree',
#  'holding',
#  'in',
#  'Accounting',
#  'Accounting',
#  'experience',
#  'in',
#  'financial',
#  'industries',
#  'Fortune',
#  '500',
#  'company',
#  'Research',
#  'background',
#  'especially',
#  'in',
#  'real',
#  'estate',
#  'industry',
#  'Comprehensive',
#  'hedge',
#  'fund',
#  'operation',
#  'knowledge',
#  'EDUCATION',
#  'The',
#  'Hong',
#  'Kong',
#  'University',
#  'of',
#  'Science',
#  'and',
#  'Technology',
#  'Master',
#  'of',
#  'Accounting',
#  'Sichuan',
#  'University',
#  'Bachelor',
#  'in',
#  'Accounting',
#  'ACCA',
#  'EXPERIENCE',
#  'All',
#  'View',
#  'Management',
#  'Ltd',
#  'Associate',
#  'Conducted',
#  'research',
#  'in',
#  'industry',
#  'and',
#  'companies',
#  'especially',
#  'in',
#  'real',
#  'estate',
#  'Hong',
#  'Kong',
#  'Sep',
#  '2014',
#  'Aug',
#  '2015',
#  'Chengdu',
#  'China',
#  'Sep',
#  '2010',
#  'Jun',
#  '2014',
#  'Hong',
#  'Kong',
#  'Sep',
#  '2015',
#  'Present',
#  'Hedge',
#  'fund',
#  'set',
#  'up',
#  'progress',
#  'and',
#  'daily',
#  'operation',
#  'gained',
#  'knowledge',
#  'about',
#  'the',
#  'regulations',
#  'taxation',
#  'settlement',
#  'etc',
#  'Took',
#  'part',
#  'in',
#  'SAP',
#  'system',
#  'built',
#  'up',
#  'process',
#  'and',
#  'perform',
#  'portfolio',
#  'management',
#  'by',
#  'SAP',
#  'work',
#  'out',
#  'financial',
#  'statements',
#  'monthly',
#  'or',
#  'yearly',
#  'Handled',
#  'pre-trading',
#  'activities',
#  'including',
#  'risk',
#  'management',
#  'mainly',
#  'on',
#  'diversification',
#  'and',
#  'margin',
#  'safety',
#  'Constructed',
#  'daily',
#  'and',
#  'periodical',
#  'P',
#  'L',
#  'reconciliations',
#  'account',
#  'settlement',
#  'Shell',
#  'China',
#  'Exploration',
#  'and',
#  'Production',
#  'Co',
#  'Ltd',
#  'Internal',
#  'Auditor',
#  'Participated',
#  'in',
#  'Internal',
#  'audit',
#  'including',
#  'year-end',
#  'stock',
#  'take',
#  'and',
#  'manpower',
#  'cost',
#  'analyze',
#  'Rebuilt',
#  'a',
#  'manpower',
#  'charges',
#  'breakdown',
#  'on',
#  'all',
#  'expense',
#  'though',
#  'extracting',
#  'all',
#  'data',
#  'for',
#  'three',
#  'years',
#  'from',
#  'SAP',
#  'analyze',
#  'and',
#  're-group',
#  'Took',
#  'learning',
#  'course',
#  'on',
#  'SAP',
#  'FICO',
#  'Chengdu',
#  'China',
#  'Oct',
#  '2013',
#  'Apr',
#  '2014',
#  'Sichuan',
#  'Taichung',
#  'Accounting',
#  'Firm',
#  'Co',
#  'Ltd',
#  'Accountant',
#  'Assisted',
#  'the',
#  'audit',
#  'process',
#  'by',
#  'reviewing',
#  'the',
#  'accounting',
#  'statements',
#  'and',
#  'preparing',
#  'audit',
#  'working',
#  'papers',
#  'for',
#  'different',
#  'types',
#  'of',
#  'enterprises',
#  'afterwards',
#  'with',
#  'last',
#  'learning',
#  'ability',
#  'Chengdu',
#  'China',
#  'June',
#  '2013',
#  'Sep',
#  '2013',
#  'CHOW',
#  'SHING',
#  'LUNG',
#  'CHESTER',
#  'Address',
#  '24D',
#  'Kwai',
#  'Chung',
#  'Fa',
#  'Yuen',
#  '52',
#  'Wo',
#  'Yi',
#  'Hop',
#  'Road',
#  'Kwai',
#  'Chung',
#  'N',
#  'T',
#  'Tel',
#  '852',
#  '9279',
#  '7979',
#  'Email',
#  'chester',
#  'sl',
#  'chow',
#  'gmail',
#  'com',
#  'WORK',
#  'EXPERIENCE',
#  'MAR',
#  '2016',
#  'PRESENT',
#  'Alibaba',
#  'Group',
#  'Company',
#  'Secretarial',
#  'Officer',
#  'To',
#  'handle',
#  'full',
#  'spectrum',
#  'of',
#  'company',
#  'secretarial',
#  'duties',
#  'for',
#  'three',
#  'listed',
#  'companies',
#  'Alibaba',
#  'Pictures',
#  'Group',
#  'Limited',
#  'Alibaba',
#  'Health',
#  'Information',
#  'Technology',
#  'Limited',
#  'and',
#  'AGTech',
#  'Holdings',
#  'Limited',
#  'To',
#  'review',
#  'and',
#  'negotiate',
#  'contracts',
#  'in',
#  'listed',
#  'companies',
#  'M',
#  'A',
#  'transactions',
#  'To',
#  'review',
#  'business',
#  'agreements',
#  'NDA',
#  'employment',
#  'contracts',
#  'and',
#  'procurement',
#  'contracts',
#  'Key',
#  'Achievement',
#  'Assisted',
#  'in',
#  'over',
#  '20',
#  'disclosable',
#  'transactions',
#  'and',
#  'connected',
#  'transactions',
#  'Reviewed',
#  'and',
#  'developed',
#  'a',
#  'group-wide',
#  'code',
#  'of',
#  'conduct',
#  'for',
#  'offices',
#  'in',
#  '17',
#  'countries',
#  'in',
#  '4',
#  'continents',
#  'with',
#  'country',
#  'specific',
#  'appendices',
#  'in',
#  'compliance',
#  'with',
#  'local',
#  'law',
#  'and',
#  'regulations',
#  'JUL',
#  '2013',
#  'FEB',
#  '2016',
#  'Luk',
#  'Fook',
#  'Holdings',
#  'International',
#  'Limited',
#  'Assistant',
#  'Company',
#  'Secretarial',
#  'Officer',
#  'Prepared',
#  'and',
#  'reviewed',
#  'annual',
#  'interim',
#  'reports',
#  'various',
#  'announcements',
#  'and',
#  'circulars',
#  'Handled',
#  'notifiable',
#  'transactions',
#  'and',
#  'connected',
#  'transactions',
#  'Held',
#  'directors',
#  'and',
#  'shareholders',
#  'meetings',
#  'and',
#  'prepared',
#  'pre',
#  'and',
#  'post-meeting',
#  'documents',
#  'including',
#  'minutes',
#  'of',
#  'board',
#  'meetings',
#  'and',
#  'committee',
#  'meetings',
#  'Made',
#  'timely',
#  'SFO',
#  'filing',
#  'via',
#  'monitoring',
#  'the',
#  'interests',
#  'of',
#  'directors',
#  'substantial',
#  'shareholders',
#  'and',
#  'concert',
#  'parties',
#  'Established',
#  'various',
#  'compliance',
#  'and',
#  'internal',
#  'control',
#  'policies',
#  'for',
#  'the',
#  'group',
#  'Advised',
#  'the',
#  'board',
#  'on',
#  'the',
#  'compliance',
#  'with',
#  'the',
#  'Listing',
#  'Rules',
#  'SFO',
#  'and',
#  'Takeovers',
#  'Code',
#  'Key',
#  'Achievement',
#  'Assisted',
#  'in',
#  'the',
#  'acquisition',
#  'of',
#  '50',
#  'interest',
#  'of',
#  'China',
#  'Gold',
#  'Silver',
#  'Group',
#  'Company',
#  'Limited',
#  '3D-GOLD',
#  'Developed',
#  'and',
#  'implemented',
#  'the',
#  'Guideline',
#  'on',
#  'Securities',
#  'Transactions',
#  'by',
#  'Directors',
#  'and',
#  'Relevant',
#  'MAR',
#  '2013',
#  'JUL',
#  '2013',
#  'Intertrust',
#  'Group',
#  'Semi',
#  'Senior',
#  'Employees',
#  'for',
#  'the',
#  'group',
#  'Handled',
#  'incorporation',
#  'of',
#  'companies',
#  'Processed',
#  'share',
#  'transfers',
#  'and',
#  'changes',
#  'of',
#  'directors',
#  'Prepared',
#  'annual',
#  'return',
#  'tax',
#  'return',
#  'and',
#  'other',
#  ...]

# %%
# before organizing
print("The total number of tokens:", len(tokens))
print("The total number of distinct tokens:", len(set(tokens)))
print("The lexical diversity:", len(tokens)/len(set(tokens)))
# Out:
# The total number of tokens: 2452
# The total number of distinct tokens: 1072
# The lexical diversity: 2.287313432835821

# %% [markdown]
# ##### * The context-independent and context-dependent (with the threshold set to %98) stop words <br> must be removed from the vocab. The stop words list (i.e,  stopwords_en.txt ) provided in the<br> zip file must be used.
# 移除stopword

# %%
# context-dependent (with the threshold set to %98)這個還沒處理

# create an empty list
stopwords_list = []

# open and read stopwords_en.txt
with open('stopwords_en.txt', 'r') as f:
    # read line by line
    for word in f.readlines():
        # remove newline
        word = word.strip()
        # append each stop word into stopwords_list
        stopwords_list.append(word)
# stopwords_list

# to create a tokens list without stopwords
filtered_tokens = [token for token in tokens if token not in stopwords_list]
filtered_tokens # tokens list without stopwords
# Out:
# ['WAN',
#  'Kin',
#  'Keung',
#  'Ken',
#  'Mobile',
#  '852',
#  '6748-8526',
#  'Email',
#  'kinkeung0531',
#  'gmail',
#  'PERSONAL',
#  'SUMMARY',
#  '4',
#  'years',
#  'working',
#  'experience',
#  'half',
#  'year',
#  'CPA',
#  'firm',
#  '3',
#  '5',
#  'years',
#  'fund',
#  'operation',
#  'experiences',
#  'AIA',
#  '2',
#  'years',
#  'supervising',
#  'experiences',
#  'Involved',
#  'due',
#  'auditing',
#  'engagements',
#  'logistics',
#  'industry',
#  'trading',
#  'manufacturing',
#  'industries',
#  'consultation',
#  'services',
#  'company',
#  'Experiences',
#  'fund',
#  'operation',
#  'valuation',
#  'regulatory',
#  'reporting',
#  'financial',
#  'analysis',
#  'Knowledge',
#  'internal',
#  'controls',
#  'risk',
#  'monitoring',
#  'WORK',
#  'EXPERIENCE',
#  'Mar',
#  '2016',
#  'Present',
#  'Senior',
#  'Associate',
#  'Accounting',
#  'Finance',
#  'AIA',
#  'Support',
#  'daily',
#  'operation',
#  'valuation',
#  'processes',
#  'fund',
#  'daily',
#  'monitoring',
#  'Support',
#  'regulatory',
#  'reporting',
#  'MPFA',
#  'Analyze',
#  'results',
#  'monitoring',
#  'performance',
#  'metrics',
#  'benchmark',
#  'forecast',
#  'historical',
#  'trends',
#  'Support',
#  'budgeting',
#  'funds',
#  'operation',
#  'Liaise',
#  'cooperate',
#  'internal',
#  'departments',
#  'risk',
#  'compliance',
#  'products',
#  'sales',
#  'agency',
#  'customer',
#  'services',
#  'external',
#  'auditors',
#  'MPFA',
#  'SFC',
#  'investment',
#  'managers',
#  'Review',
#  'restructure',
#  'working',
#  'procedures',
#  'improve',
#  'operation',
#  'efficiency',
#  'Support',
#  'firm',
#  'wide',
#  'departmental',
#  'projects',
#  'product',
#  'launch',
#  'scheme',
#  'merger',
#  'streamline',
#  'workflow',
#  'processes',
#  'BU',
#  'Associate',
#  'Accounting',
#  'Finance',
#  'AIA',
#  'Support',
#  'fund',
#  'valuation',
#  'team',
#  'perform',
#  'daily',
#  'fund',
#  'operation',
#  'valuation',
#  'processes',
#  'Analyzing',
#  'operations',
#  'fund',
#  'performance',
#  'results',
#  'monitoring',
#  'variances',
#  'Conducting',
#  'analytical',
#  'reviews',
#  'financial',
#  'transaction',
#  'identify',
#  'unusual',
#  'price',
#  'fluctuations',
#  'Assessing',
#  'internal',
#  'control',
#  'procedure',
#  'compliance',
#  'requirements',
#  'Reviewing',
#  'appropriateness',
#  'completeness',
#  'financial',
#  'statements',
#  'accounts',
#  'disclosures',
#  'HKFRS',
#  'Liaise',
#  'cooperate',
#  'external',
#  'auditors',
#  'compliance',
#  'departments',
#  'SFC',
#  'MPFA',
#  'Assist',
#  'Manager',
#  'special',
#  'projects',
#  'team',
#  'project',
#  'planning',
#  'analysis',
#  'system',
#  'transformation',
#  'UAT',
#  'Jan',
#  '2014',
#  'Feb',
#  '2016',
#  'Aug',
#  '2013',
#  'Dec',
#  '2013',
#  'Auditor',
#  'Cheer',
#  'Link',
#  'CPA',
#  'Limited',
#  'Assignment',
#  'audit',
#  'engagements',
#  'clients',
#  'natures',
#  'sizes',
#  'business',
#  'Conducting',
#  'analytical',
#  'reviews',
#  'financial',
#  'statements',
#  'identify',
#  'unusual',
#  'fluctuations',
#  'potential',
#  'risk',
#  'exposure',
#  'Reviewing',
#  'appropriateness',
#  'completeness',
#  'financial',
#  'statements',
#  'accounts',
#  'disclosures',
#  'HKFRS',
#  'Solid',
#  'understanding',
#  'accounting',
#  'process',
#  'performing',
#  'walkthrough',
#  'validating',
#  'relevant',
#  'control',
#  'procedures',
#  'Assessing',
#  'fair',
#  'values',
#  'private',
#  'equities',
#  'financial',
#  'derivatives',
#  'valuation',
#  'methodology',
#  'Conducting',
#  'sensitivity',
#  'analysis',
#  'evaluate',
#  'market',
#  'price',
#  'risk',
#  'interest',
#  'rate',
#  'risk',
#  'credit',
#  'risk',
#  'liquidity',
#  'risk',
#  'Collaborating',
#  'tax',
#  'department',
#  'corporate',
#  'tax',
#  'issues',
#  'EDUCATION',
#  'City',
#  'University',
#  'Hong',
#  'Kong',
#  'Aug',
#  '2010',
#  'Jul',
#  '2013',
#  'Bachelor',
#  'Business',
#  'Administration',
#  'Honours',
#  'Accountancy',
#  'Management',
#  'Information',
#  'Systems',
#  'Tin',
#  'Shui',
#  'Wai',
#  'Government',
#  'Secondary',
#  'School',
#  'Sept',
#  '2003',
#  'Jun',
#  '2010',
#  'EXTRA-CURRICULAR',
#  'ACTIVITIES',
#  '2012',
#  '13',
#  '2011',
#  '12',
#  '2010',
#  '11',
#  'Chairperson',
#  'Election',
#  'Board',
#  'HSBC',
#  'Prosperity',
#  'Hall',
#  'Chairperson',
#  'Residents',
#  'Association',
#  'Council',
#  'President',
#  'Residents',
#  'Association',
#  'Executive',
#  'Committee',
#  'PROFESSIONAL',
#  'QUALIFICATIONS',
#  '07',
#  '2010',
#  'Present',
#  'Student',
#  'Member',
#  'Hong',
#  'Kong',
#  'Institute',
#  'Certified',
#  'Public',
#  'Accountants',
#  'SPECIAL',
#  'SKILLS',
#  'Languages',
#  'Fluent',
#  'English',
#  'written',
#  'spoken',
#  'Native',
#  'Chinese',
#  'written',
#  'spoken',
#  'Fluent',
#  'Putonghua',
#  'Strengths',
#  'Strong',
#  'interpersonal',
#  'skill',
#  'communication',
#  'skill',
#  'quick',
#  'learner',
#  'highly',
#  'adaptable',
#  'change',
#  'strong',
#  'analytical',
#  'skills',
#  'problem',
#  'solving',
#  'skill',
#  'Others',
#  'Advanced',
#  'MS',
#  'Office',
#  'Excel',
#  'Word',
#  'PowerPoint',
#  'Access',
#  'Chinese',
#  'English',
#  'word',
#  'processing',
#  'CURRENT',
#  'SALARY',
#  'HK',
#  '22',
#  '000',
#  'month',
#  'included',
#  'allowance',
#  'EXPECTED',
#  'SALARY',
#  'HK',
#  '26',
#  '000',
#  'month',
#  'AVAILABILITY',
#  '1-month',
#  'notice',
#  'YANG',
#  'TAMMIE',
#  'QI',
#  '杨',
#  '琪',
#  'Email',
#  'qyangaf',
#  'gmail',
#  'Mobile',
#  '852',
#  '6020',
#  '4161',
#  'HILIGHTS',
#  'Completed',
#  'ACCA',
#  'professional',
#  'examinations',
#  'Mater',
#  'degree',
#  'holding',
#  'Accounting',
#  'Accounting',
#  'experience',
#  'financial',
#  'industries',
#  'Fortune',
#  '500',
#  'company',
#  'Research',
#  'background',
#  'real',
#  'estate',
#  'industry',
#  'Comprehensive',
#  'hedge',
#  'fund',
#  'operation',
#  'knowledge',
#  'EDUCATION',
#  'The',
#  'Hong',
#  'Kong',
#  'University',
#  'Science',
#  'Technology',
#  'Master',
#  'Accounting',
#  'Sichuan',
#  'University',
#  'Bachelor',
#  'Accounting',
#  'ACCA',
#  'EXPERIENCE',
#  'All',
#  'View',
#  'Management',
#  'Ltd',
#  'Associate',
#  'Conducted',
#  'research',
#  'industry',
#  'companies',
#  'real',
#  'estate',
#  'Hong',
#  'Kong',
#  'Sep',
#  '2014',
#  'Aug',
#  '2015',
#  'Chengdu',
#  'China',
#  'Sep',
#  '2010',
#  'Jun',
#  '2014',
#  'Hong',
#  'Kong',
#  'Sep',
#  '2015',
#  'Present',
#  'Hedge',
#  'fund',
#  'set',
#  'progress',
#  'daily',
#  'operation',
#  'gained',
#  'knowledge',
#  'regulations',
#  'taxation',
#  'settlement',
#  'Took',
#  'part',
#  'SAP',
#  'system',
#  'built',
#  'process',
#  'perform',
#  'portfolio',
#  'management',
#  'SAP',
#  'work',
#  'financial',
#  'statements',
#  'monthly',
#  'yearly',
#  'Handled',
#  'pre-trading',
#  'activities',
#  'including',
#  'risk',
#  'management',
#  'diversification',
#  'margin',
#  'safety',
#  'Constructed',
#  'daily',
#  'periodical',
#  'P',
#  'L',
#  'reconciliations',
#  'account',
#  'settlement',
#  'Shell',
#  'China',
#  'Exploration',
#  'Production',
#  'Co',
#  'Ltd',
#  'Internal',
#  'Auditor',
#  'Participated',
#  'Internal',
#  'audit',
#  'including',
#  'year-end',
#  'stock',
#  'manpower',
#  'cost',
#  'analyze',
#  'Rebuilt',
#  'manpower',
#  'charges',
#  'breakdown',
#  'expense',
#  'extracting',
#  'data',
#  'years',
#  'SAP',
#  'analyze',
#  're-group',
#  'Took',
#  'learning',
#  'SAP',
#  'FICO',
#  'Chengdu',
#  'China',
#  'Oct',
#  '2013',
#  'Apr',
#  '2014',
#  'Sichuan',
#  'Taichung',
#  'Accounting',
#  'Firm',
#  'Co',
#  'Ltd',
#  'Accountant',
#  'Assisted',
#  'audit',
#  'process',
#  'reviewing',
#  'accounting',
#  'statements',
#  'preparing',
#  'audit',
#  'working',
#  'papers',
#  'types',
#  'enterprises',
#  'learning',
#  'ability',
#  'Chengdu',
#  'China',
#  'June',
#  '2013',
#  'Sep',
#  '2013',
#  'CHOW',
#  'SHING',
#  'LUNG',
#  'CHESTER',
#  'Address',
#  '24D',
#  'Kwai',
#  'Chung',
#  'Fa',
#  'Yuen',
#  '52',
#  'Wo',
#  'Yi',
#  'Hop',
#  'Road',
#  'Kwai',
#  'Chung',
#  'N',
#  'T',
#  'Tel',
#  '852',
#  '9279',
#  '7979',
#  'Email',
#  'chester',
#  'sl',
#  'chow',
#  'gmail',
#  'WORK',
#  'EXPERIENCE',
#  'MAR',
#  '2016',
#  'PRESENT',
#  'Alibaba',
#  'Group',
#  'Company',
#  'Secretarial',
#  'Officer',
#  'To',
#  'handle',
#  'full',
#  'spectrum',
#  'company',
#  'secretarial',
#  'duties',
#  'listed',
#  'companies',
#  'Alibaba',
#  'Pictures',
#  'Group',
#  'Limited',
#  'Alibaba',
#  'Health',
#  'Information',
#  'Technology',
#  'Limited',
#  'AGTech',
#  'Holdings',
#  'Limited',
#  'To',
#  'review',
#  'negotiate',
#  'contracts',
#  'listed',
#  'companies',
#  'M',
#  'A',
#  'transactions',
#  'To',
#  'review',
#  'business',
#  'agreements',
#  'NDA',
#  'employment',
#  'contracts',
#  'procurement',
#  'contracts',
#  'Key',
#  'Achievement',
#  'Assisted',
#  '20',
#  'disclosable',
#  'transactions',
#  'connected',
#  'transactions',
#  'Reviewed',
#  'developed',
#  'group-wide',
#  'code',
#  'conduct',
#  'offices',
#  '17',
#  'countries',
#  '4',
#  'continents',
#  'country',
#  'specific',
#  'appendices',
#  'compliance',
#  'local',
#  'law',
#  'regulations',
#  'JUL',
#  '2013',
#  'FEB',
#  '2016',
#  'Luk',
#  'Fook',
#  'Holdings',
#  'International',
#  'Limited',
#  'Assistant',
#  'Company',
#  'Secretarial',
#  'Officer',
#  'Prepared',
#  'reviewed',
#  'annual',
#  'interim',
#  'reports',
#  'announcements',
#  'circulars',
#  'Handled',
#  'notifiable',
#  'transactions',
#  'connected',
#  'transactions',
#  'Held',
#  'directors',
#  'shareholders',
#  'meetings',
#  'prepared',
#  'pre',
#  'post-meeting',
#  'documents',
#  'including',
#  'minutes',
#  'board',
#  'meetings',
#  'committee',
#  'meetings',
#  'Made',
#  'timely',
#  'SFO',
#  'filing',
#  'monitoring',
#  'interests',
#  'directors',
#  'substantial',
#  'shareholders',
#  'concert',
#  'parties',
#  'Established',
#  'compliance',
#  'internal',
#  'control',
#  'policies',
#  'group',
#  'Advised',
#  'board',
#  'compliance',
#  'Listing',
#  'Rules',
#  'SFO',
#  'Takeovers',
#  'Code',
#  'Key',
#  'Achievement',
#  'Assisted',
#  'acquisition',
#  '50',
#  'interest',
#  'China',
#  'Gold',
#  'Silver',
#  'Group',
#  'Company',
#  'Limited',
#  '3D-GOLD',
#  'Developed',
#  'implemented',
#  'Guideline',
#  'Securities',
#  'Transactions',
#  'Directors',
#  'Relevant',
#  'MAR',
#  '2013',
#  'JUL',
#  '2013',
#  'Intertrust',
#  'Group',
#  'Semi',
#  'Senior',
#  'Employees',
#  'group',
#  'Handled',
#  'incorporation',
#  'companies',
#  'Processed',
#  'share',
#  'transfers',
#  'directors',
#  'Prepared',
#  'annual',
#  'return',
#  'tax',
#  'return',
#  'statutory',
#  'documents',
#  'Maintained',
#  'statutory',
#  'registers',
#  'companies',
#  'Arranged',
#  'opening',
#  'bank',
#  'accounts',
#  'JUL',
#  '2010',
#  'MAR',
#  '2013',
#  'Tricor',
#  'Services',
#  'Limited',
#  'Officer',
#  'Provided',
#  'full',
#  'spectrum',
#  'company',
#  'secretarial',
#  'advisory',
#  'services',
#  'listed',
#  'clients',
#  'Reviewed',
#  'annual',
#  'interim',
#  'reports',
#  'announcements',
#  'circulars',
#  'Reviewed',
#  'IPO',
#  'prospectus',
#  'application',
#  'forms',
#  'Prepared',
#  'annual',
#  'return',
#  'tax',
#  'return',
#  'statutory',
#  'documents',
#  'Liaised',
#  'banks',
#  'prepared',
#  'bank',
#  'account',
#  'opening',
#  'documents',
#  'Handled',
#  'ad-hoc',
#  'assignments',
#  'alternation',
#  'M',
#  'A',
#  'change',
#  'company',
#  'names',
#  'Key',
#  'Achievement',
#  'EDUCATION',
#  'Assisted',
#  'IPO',
#  'Chow',
#  'Tai',
#  'Fuk',
#  'Jewellery',
#  'Group',
#  'Limited',
#  '2012',
#  '2016',
#  '2018',
#  'Master',
#  'Corporate',
#  'Governance',
#  'The',
#  'Hong',
#  'Kong',
#  'Polytechnic',
#  'University',
#  '2012',
#  '2015',
#  'Bachelor',
#  'Business',
#  'Administration',
#  'Hons',
#  'Corporate',
#  'Administration',
#  'The',
#  'Open',
#  'University',
#  'Hong',
#  'Kong',
#  '2008',
#  '2010',
#  'Associate',
#  'Arts',
#  'English',
#  'Business',
#  'Communication',
#  '2003',
#  '2005',
#  'S',
#  'K',
#  'H',
#  'Li',
#  'Ping',
#  'Secondary',
#  'School',
#  'Secondary',
#  '6-7',
#  'The',
#  'Hong',
#  'Kong',
#  'Polytechnic',
#  'University',
#  'Hong',
#  'Kong',
#  'Community',
#  'College',
#  'Obtained',
#  'A',
#  'Reading',
#  'Language',
#  'Systems',
#  'Use',
#  'English',
#  'HKALE',
#  '2005',
#  '1998',
#  '2003',
#  'Po',
#  'Leung',
#  'Kuk',
#  'Lee',
#  'Shing',
#  'Pik',
#  'College',
#  'Secondary',
#  '1-5',
#  'REFERENCES',
#  'AVAILABLE',
#  'ON',
#  'REQUEST',
#  '1',
#  'SKILLS',
#  'CHOW',
#  'SHING',
#  'LUNG',
#  'CHESTER',
#  'Address',
#  '24D',
#  'Kwai',
#  'Chung',
#  'Fa',
#  'Yuen',
#  '52',
#  'Wo',
#  'Yi',
#  'Hop',
#  'Road',
#  'Kwai',
#  'Chung',
#  'N',
#  'T',
#  'Tel',
#  '852',
#  '9279',
#  '7979',
#  'Email',
#  'chester',
#  'sl',
#  'chow',
#  'gmail',
#  'Language',
#  'Excellent',
#  'command',
#  'written',
#  'English',
#  'British',
#  'Chinese',
#  'traditional',
#  'simplified',
#  'Fluent',
#  'spoken',
#  'English',
#  'Cantonese',
#  'Putonghua',
#  'Computer',
#  'CSA',
#  'MS',
#  'Word',
#  'Excel',
#  'Power',
#  'Point',
#  'English',
#  'Chinese',
#  'Word',
#  'Processing',
#  'Typing',
#  'English',
#  '70',
#  'wpm',
#  'Chinese',
#  '60',
#  'wpm',
#  'SALARY',
#  'Current',
#  'HK',
#  ...]

# %% [markdown]
# ##### * Tokens should be stemmed using the Porter stemmer.

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
['{0} -> {1}'.format(word, stemmer.stem(word)) for word in filtered_tokens]
# Out:
# ['WAN -> wan',
#  'Kin -> kin',
#  'Keung -> keung',
#  'Ken -> ken',
#  'Mobile -> mobil',
#  '852 -> 852',
#  '6748-8526 -> 6748-8526',
#  'Email -> email',
#  'kinkeung0531 -> kinkeung0531',
#  'gmail -> gmail',
#  'PERSONAL -> person',
#  'SUMMARY -> summari',
#  '4 -> 4',
#  'years -> year',
#  'working -> work',
#  'experience -> experi',
#  'half -> half',
#  'year -> year',
#  'CPA -> cpa',
#  'firm -> firm',
#  '3 -> 3',
#  '5 -> 5',
#  'years -> year',
#  'fund -> fund',
#  'operation -> oper',
#  'experiences -> experi',
#  'AIA -> aia',
#  '2 -> 2',
#  'years -> year',
#  'supervising -> supervis',
#  'experiences -> experi',
#  'Involved -> involv',
#  'due -> due',
#  'auditing -> audit',
#  'engagements -> engag',
#  'logistics -> logist',
#  'industry -> industri',
#  'trading -> trade',
#  'manufacturing -> manufactur',
#  'industries -> industri',
#  'consultation -> consult',
#  'services -> servic',
#  'company -> compani',
#  'Experiences -> experi',
#  'fund -> fund',
#  'operation -> oper',
#  'valuation -> valuat',
#  'regulatory -> regulatori',
#  'reporting -> report',
#  'financial -> financi',
#  'analysis -> analysi',
#  'Knowledge -> knowledg',
#  'internal -> intern',
#  'controls -> control',
#  'risk -> risk',
#  'monitoring -> monitor',
#  'WORK -> work',
#  'EXPERIENCE -> experi',
#  'Mar -> mar',
#  '2016 -> 2016',
#  'Present -> present',
#  'Senior -> senior',
#  'Associate -> associ',
#  'Accounting -> account',
#  'Finance -> financ',
#  'AIA -> aia',
#  'Support -> support',
#  'daily -> daili',
#  'operation -> oper',
#  'valuation -> valuat',
#  'processes -> process',
#  'fund -> fund',
#  'daily -> daili',
#  'monitoring -> monitor',
#  'Support -> support',
#  'regulatory -> regulatori',
#  'reporting -> report',
#  'MPFA -> mpfa',
#  'Analyze -> analyz',
#  'results -> result',
#  'monitoring -> monitor',
#  'performance -> perform',
#  'metrics -> metric',
#  'benchmark -> benchmark',
#  'forecast -> forecast',
#  'historical -> histor',
#  'trends -> trend',
#  'Support -> support',
#  'budgeting -> budget',
#  'funds -> fund',
#  'operation -> oper',
#  'Liaise -> liais',
#  'cooperate -> cooper',
#  'internal -> intern',
#  'departments -> depart',
#  'risk -> risk',
#  'compliance -> complianc',
#  'products -> product',
#  'sales -> sale',
#  'agency -> agenc',
#  'customer -> custom',
#  'services -> servic',
#  'external -> extern',
#  'auditors -> auditor',
#  'MPFA -> mpfa',
#  'SFC -> sfc',
#  'investment -> invest',
#  'managers -> manag',
#  'Review -> review',
#  'restructure -> restructur',
#  'working -> work',
#  'procedures -> procedur',
#  'improve -> improv',
#  'operation -> oper',
#  'efficiency -> effici',
#  'Support -> support',
#  'firm -> firm',
#  'wide -> wide',
#  'departmental -> department',
#  'projects -> project',
#  'product -> product',
#  'launch -> launch',
#  'scheme -> scheme',
#  'merger -> merger',
#  'streamline -> streamlin',
#  'workflow -> workflow',
#  'processes -> process',
#  'BU -> BU',
#  'Associate -> associ',
#  'Accounting -> account',
#  'Finance -> financ',
#  'AIA -> aia',
#  'Support -> support',
#  'fund -> fund',
#  'valuation -> valuat',
#  'team -> team',
#  'perform -> perform',
#  'daily -> daili',
#  'fund -> fund',
#  'operation -> oper',
#  'valuation -> valuat',
#  'processes -> process',
#  'Analyzing -> analyz',
#  'operations -> oper',
#  'fund -> fund',
#  'performance -> perform',
#  'results -> result',
#  'monitoring -> monitor',
#  'variances -> varianc',
#  'Conducting -> conduct',
#  'analytical -> analyt',
#  'reviews -> review',
#  'financial -> financi',
#  'transaction -> transact',
#  'identify -> identifi',
#  'unusual -> unusu',
#  'price -> price',
#  'fluctuations -> fluctuat',
#  'Assessing -> assess',
#  'internal -> intern',
#  'control -> control',
#  'procedure -> procedur',
#  'compliance -> complianc',
#  'requirements -> requir',
#  'Reviewing -> review',
#  'appropriateness -> appropri',
#  'completeness -> complet',
#  'financial -> financi',
#  'statements -> statement',
#  'accounts -> account',
#  'disclosures -> disclosur',
#  'HKFRS -> hkfr',
#  'Liaise -> liais',
#  'cooperate -> cooper',
#  'external -> extern',
#  'auditors -> auditor',
#  'compliance -> complianc',
#  'departments -> depart',
#  'SFC -> sfc',
#  'MPFA -> mpfa',
#  'Assist -> assist',
#  'Manager -> manag',
#  'special -> special',
#  'projects -> project',
#  'team -> team',
#  'project -> project',
#  'planning -> plan',
#  'analysis -> analysi',
#  'system -> system',
#  'transformation -> transform',
#  'UAT -> uat',
#  'Jan -> jan',
#  '2014 -> 2014',
#  'Feb -> feb',
#  '2016 -> 2016',
#  'Aug -> aug',
#  '2013 -> 2013',
#  'Dec -> dec',
#  '2013 -> 2013',
#  'Auditor -> auditor',
#  'Cheer -> cheer',
#  'Link -> link',
#  'CPA -> cpa',
#  'Limited -> limit',
#  'Assignment -> assign',
#  'audit -> audit',
#  'engagements -> engag',
#  'clients -> client',
#  'natures -> natur',
#  'sizes -> size',
#  'business -> busi',
#  'Conducting -> conduct',
#  'analytical -> analyt',
#  'reviews -> review',
#  'financial -> financi',
#  'statements -> statement',
#  'identify -> identifi',
#  'unusual -> unusu',
#  'fluctuations -> fluctuat',
#  'potential -> potenti',
#  'risk -> risk',
#  'exposure -> exposur',
#  'Reviewing -> review',
#  'appropriateness -> appropri',
#  'completeness -> complet',
#  'financial -> financi',
#  'statements -> statement',
#  'accounts -> account',
#  'disclosures -> disclosur',
#  'HKFRS -> hkfr',
#  'Solid -> solid',
#  'understanding -> understand',
#  'accounting -> account',
#  'process -> process',
#  'performing -> perform',
#  'walkthrough -> walkthrough',
#  'validating -> valid',
#  'relevant -> relev',
#  'control -> control',
#  'procedures -> procedur',
#  'Assessing -> assess',
#  'fair -> fair',
#  'values -> valu',
#  'private -> privat',
#  'equities -> equiti',
#  'financial -> financi',
#  'derivatives -> deriv',
#  'valuation -> valuat',
#  'methodology -> methodolog',
#  'Conducting -> conduct',
#  'sensitivity -> sensit',
#  'analysis -> analysi',
#  'evaluate -> evalu',
#  'market -> market',
#  'price -> price',
#  'risk -> risk',
#  'interest -> interest',
#  'rate -> rate',
#  'risk -> risk',
#  'credit -> credit',
#  'risk -> risk',
#  'liquidity -> liquid',
#  'risk -> risk',
#  'Collaborating -> collabor',
#  'tax -> tax',
#  'department -> depart',
#  'corporate -> corpor',
#  'tax -> tax',
#  'issues -> issu',
#  'EDUCATION -> educ',
#  'City -> citi',
#  'University -> univers',
#  'Hong -> hong',
#  'Kong -> kong',
#  'Aug -> aug',
#  '2010 -> 2010',
#  'Jul -> jul',
#  '2013 -> 2013',
#  'Bachelor -> bachelor',
#  'Business -> busi',
#  'Administration -> administr',
#  'Honours -> honour',
#  'Accountancy -> account',
#  'Management -> manag',
#  'Information -> inform',
#  'Systems -> system',
#  'Tin -> tin',
#  'Shui -> shui',
#  'Wai -> wai',
#  'Government -> govern',
#  'Secondary -> secondari',
#  'School -> school',
#  'Sept -> sept',
#  '2003 -> 2003',
#  'Jun -> jun',
#  '2010 -> 2010',
#  'EXTRA-CURRICULAR -> extra-curricular',
#  'ACTIVITIES -> activ',
#  '2012 -> 2012',
#  '13 -> 13',
#  '2011 -> 2011',
#  '12 -> 12',
#  '2010 -> 2010',
#  '11 -> 11',
#  'Chairperson -> chairperson',
#  'Election -> elect',
#  'Board -> board',
#  'HSBC -> hsbc',
#  'Prosperity -> prosper',
#  'Hall -> hall',
#  'Chairperson -> chairperson',
#  'Residents -> resid',
#  'Association -> associ',
#  'Council -> council',
#  'President -> presid',
#  'Residents -> resid',
#  'Association -> associ',
#  'Executive -> execut',
#  'Committee -> committe',
#  'PROFESSIONAL -> profession',
#  'QUALIFICATIONS -> qualif',
#  '07 -> 07',
#  '2010 -> 2010',
#  'Present -> present',
#  'Student -> student',
#  'Member -> member',
#  'Hong -> hong',
#  'Kong -> kong',
#  'Institute -> institut',
#  'Certified -> certifi',
#  'Public -> public',
#  'Accountants -> account',
#  'SPECIAL -> special',
#  'SKILLS -> skill',
#  'Languages -> languag',
#  'Fluent -> fluent',
#  'English -> english',
#  'written -> written',
#  'spoken -> spoken',
#  'Native -> nativ',
#  'Chinese -> chines',
#  'written -> written',
#  'spoken -> spoken',
#  'Fluent -> fluent',
#  'Putonghua -> putonghua',
#  'Strengths -> strength',
#  'Strong -> strong',
#  'interpersonal -> interperson',
#  'skill -> skill',
#  'communication -> commun',
#  'skill -> skill',
#  'quick -> quick',
#  'learner -> learner',
#  'highly -> highli',
#  'adaptable -> adapt',
#  'change -> chang',
#  'strong -> strong',
#  'analytical -> analyt',
#  'skills -> skill',
#  'problem -> problem',
#  'solving -> solv',
#  'skill -> skill',
#  'Others -> other',
#  'Advanced -> advanc',
#  'MS -> MS',
#  'Office -> offic',
#  'Excel -> excel',
#  'Word -> word',
#  'PowerPoint -> powerpoint',
#  'Access -> access',
#  'Chinese -> chines',
#  'English -> english',
#  'word -> word',
#  'processing -> process',
#  'CURRENT -> current',
#  'SALARY -> salari',
#  'HK -> HK',
#  '22 -> 22',
#  '000 -> 000',
#  'month -> month',
#  'included -> includ',
#  'allowance -> allow',
#  'EXPECTED -> expect',
#  'SALARY -> salari',
#  'HK -> HK',
#  '26 -> 26',
#  '000 -> 000',
#  'month -> month',
#  'AVAILABILITY -> avail',
#  '1-month -> 1-month',
#  'notice -> notic',
#  'YANG -> yang',
#  'TAMMIE -> tammi',
#  'QI -> QI',
#  '杨 -> 杨',
#  '琪 -> 琪',
#  'Email -> email',
#  'qyangaf -> qyangaf',
#  'gmail -> gmail',
#  'Mobile -> mobil',
#  '852 -> 852',
#  '6020 -> 6020',
#  '4161 -> 4161',
#  'HILIGHTS -> hilight',
#  'Completed -> complet',
#  'ACCA -> acca',
#  'professional -> profession',
#  'examinations -> examin',
#  'Mater -> mater',
#  'degree -> degre',
#  'holding -> hold',
#  'Accounting -> account',
#  'Accounting -> account',
#  'experience -> experi',
#  'financial -> financi',
#  'industries -> industri',
#  'Fortune -> fortun',
#  '500 -> 500',
#  'company -> compani',
#  'Research -> research',
#  'background -> background',
#  'real -> real',
#  'estate -> estat',
#  'industry -> industri',
#  'Comprehensive -> comprehens',
#  'hedge -> hedg',
#  'fund -> fund',
#  'operation -> oper',
#  'knowledge -> knowledg',
#  'EDUCATION -> educ',
#  'The -> the',
#  'Hong -> hong',
#  'Kong -> kong',
#  'University -> univers',
#  'Science -> scienc',
#  'Technology -> technolog',
#  'Master -> master',
#  'Accounting -> account',
#  'Sichuan -> sichuan',
#  'University -> univers',
#  'Bachelor -> bachelor',
#  'Accounting -> account',
#  'ACCA -> acca',
#  'EXPERIENCE -> experi',
#  'All -> all',
#  'View -> view',
#  'Management -> manag',
#  'Ltd -> ltd',
#  'Associate -> associ',
#  'Conducted -> conduct',
#  'research -> research',
#  'industry -> industri',
#  'companies -> compani',
#  'real -> real',
#  'estate -> estat',
#  'Hong -> hong',
#  'Kong -> kong',
#  'Sep -> sep',
#  '2014 -> 2014',
#  'Aug -> aug',
#  '2015 -> 2015',
#  'Chengdu -> chengdu',
#  'China -> china',
#  'Sep -> sep',
#  '2010 -> 2010',
#  'Jun -> jun',
#  '2014 -> 2014',
#  'Hong -> hong',
#  'Kong -> kong',
#  'Sep -> sep',
#  '2015 -> 2015',
#  'Present -> present',
#  'Hedge -> hedg',
#  'fund -> fund',
#  'set -> set',
#  'progress -> progress',
#  'daily -> daili',
#  'operation -> oper',
#  'gained -> gain',
#  'knowledge -> knowledg',
#  'regulations -> regul',
#  'taxation -> taxat',
#  'settlement -> settlement',
#  'Took -> took',
#  'part -> part',
#  'SAP -> sap',
#  'system -> system',
#  'built -> built',
#  'process -> process',
#  'perform -> perform',
#  'portfolio -> portfolio',
#  'management -> manag',
#  'SAP -> sap',
#  'work -> work',
#  'financial -> financi',
#  'statements -> statement',
#  'monthly -> monthli',
#  'yearly -> yearli',
#  'Handled -> handl',
#  'pre-trading -> pre-trad',
#  'activities -> activ',
#  'including -> includ',
#  'risk -> risk',
#  'management -> manag',
#  'diversification -> diversif',
#  'margin -> margin',
#  'safety -> safeti',
#  'Constructed -> construct',
#  'daily -> daili',
#  'periodical -> period',
#  'P -> P',
#  'L -> L',
#  'reconciliations -> reconcili',
#  'account -> account',
#  'settlement -> settlement',
#  'Shell -> shell',
#  'China -> china',
#  'Exploration -> explor',
#  'Production -> product',
#  'Co -> Co',
#  'Ltd -> ltd',
#  'Internal -> intern',
#  'Auditor -> auditor',
#  'Participated -> particip',
#  'Internal -> intern',
#  'audit -> audit',
#  'including -> includ',
#  'year-end -> year-end',
#  'stock -> stock',
#  'manpower -> manpow',
#  'cost -> cost',
#  'analyze -> analyz',
#  'Rebuilt -> rebuilt',
#  'manpower -> manpow',
#  'charges -> charg',
#  'breakdown -> breakdown',
#  'expense -> expens',
#  'extracting -> extract',
#  'data -> data',
#  'years -> year',
#  'SAP -> sap',
#  'analyze -> analyz',
#  're-group -> re-group',
#  'Took -> took',
#  'learning -> learn',
#  'SAP -> sap',
#  'FICO -> fico',
#  'Chengdu -> chengdu',
#  'China -> china',
#  'Oct -> oct',
#  '2013 -> 2013',
#  'Apr -> apr',
#  '2014 -> 2014',
#  'Sichuan -> sichuan',
#  'Taichung -> taichung',
#  'Accounting -> account',
#  'Firm -> firm',
#  'Co -> Co',
#  'Ltd -> ltd',
#  'Accountant -> account',
#  'Assisted -> assist',
#  'audit -> audit',
#  'process -> process',
#  'reviewing -> review',
#  'accounting -> account',
#  'statements -> statement',
#  'preparing -> prepar',
#  'audit -> audit',
#  'working -> work',
#  'papers -> paper',
#  'types -> type',
#  'enterprises -> enterpris',
#  'learning -> learn',
#  'ability -> abil',
#  'Chengdu -> chengdu',
#  'China -> china',
#  'June -> june',
#  '2013 -> 2013',
#  'Sep -> sep',
#  '2013 -> 2013',
#  'CHOW -> chow',
#  'SHING -> shing',
#  'LUNG -> lung',
#  'CHESTER -> chester',
#  'Address -> address',
#  '24D -> 24d',
#  'Kwai -> kwai',
#  'Chung -> chung',
#  'Fa -> Fa',
#  'Yuen -> yuen',
#  '52 -> 52',
#  'Wo -> Wo',
#  'Yi -> Yi',
#  'Hop -> hop',
#  'Road -> road',
#  'Kwai -> kwai',
#  'Chung -> chung',
#  'N -> N',
#  'T -> T',
#  'Tel -> tel',
#  '852 -> 852',
#  '9279 -> 9279',
#  '7979 -> 7979',
#  'Email -> email',
#  'chester -> chester',
#  'sl -> sl',
#  'chow -> chow',
#  'gmail -> gmail',
#  'WORK -> work',
#  'EXPERIENCE -> experi',
#  'MAR -> mar',
#  '2016 -> 2016',
#  'PRESENT -> present',
#  'Alibaba -> alibaba',
#  'Group -> group',
#  'Company -> compani',
#  'Secretarial -> secretari',
#  'Officer -> offic',
#  'To -> To',
#  'handle -> handl',
#  'full -> full',
#  'spectrum -> spectrum',
#  'company -> compani',
#  'secretarial -> secretari',
#  'duties -> duti',
#  'listed -> list',
#  'companies -> compani',
#  'Alibaba -> alibaba',
#  'Pictures -> pictur',
#  'Group -> group',
#  'Limited -> limit',
#  'Alibaba -> alibaba',
#  'Health -> health',
#  'Information -> inform',
#  'Technology -> technolog',
#  'Limited -> limit',
#  'AGTech -> agtech',
#  'Holdings -> hold',
#  'Limited -> limit',
#  'To -> To',
#  'review -> review',
#  'negotiate -> negoti',
#  'contracts -> contract',
#  'listed -> list',
#  'companies -> compani',
#  'M -> M',
#  'A -> A',
#  'transactions -> transact',
#  'To -> To',
#  'review -> review',
#  'business -> busi',
#  'agreements -> agreement',
#  'NDA -> nda',
#  'employment -> employ',
#  'contracts -> contract',
#  'procurement -> procur',
#  'contracts -> contract',
#  'Key -> key',
#  'Achievement -> achiev',
#  'Assisted -> assist',
#  '20 -> 20',
#  'disclosable -> disclos',
#  'transactions -> transact',
#  'connected -> connect',
#  'transactions -> transact',
#  'Reviewed -> review',
#  'developed -> develop',
#  'group-wide -> group-wid',
#  'code -> code',
#  'conduct -> conduct',
#  'offices -> offic',
#  '17 -> 17',
#  'countries -> countri',
#  '4 -> 4',
#  'continents -> contin',
#  'country -> countri',
#  'specific -> specif',
#  'appendices -> appendic',
#  'compliance -> complianc',
#  'local -> local',
#  'law -> law',
#  'regulations -> regul',
#  'JUL -> jul',
#  '2013 -> 2013',
#  'FEB -> feb',
#  '2016 -> 2016',
#  'Luk -> luk',
#  'Fook -> fook',
#  'Holdings -> hold',
#  'International -> intern',
#  'Limited -> limit',
#  'Assistant -> assist',
#  'Company -> compani',
#  'Secretarial -> secretari',
#  'Officer -> offic',
#  'Prepared -> prepar',
#  'reviewed -> review',
#  'annual -> annual',
#  'interim -> interim',
#  'reports -> report',
#  'announcements -> announc',
#  'circulars -> circular',
#  'Handled -> handl',
#  'notifiable -> notifi',
#  'transactions -> transact',
#  'connected -> connect',
#  'transactions -> transact',
#  'Held -> held',
#  'directors -> director',
#  'shareholders -> sharehold',
#  'meetings -> meet',
#  'prepared -> prepar',
#  'pre -> pre',
#  'post-meeting -> post-meet',
#  'documents -> document',
#  'including -> includ',
#  'minutes -> minut',
#  'board -> board',
#  'meetings -> meet',
#  'committee -> committe',
#  'meetings -> meet',
#  'Made -> made',
#  'timely -> time',
#  'SFO -> sfo',
#  'filing -> file',
#  'monitoring -> monitor',
#  'interests -> interest',
#  'directors -> director',
#  'substantial -> substanti',
#  'shareholders -> sharehold',
#  'concert -> concert',
#  'parties -> parti',
#  'Established -> establish',
#  'compliance -> complianc',
#  'internal -> intern',
#  'control -> control',
#  'policies -> polici',
#  'group -> group',
#  'Advised -> advis',
#  'board -> board',
#  'compliance -> complianc',
#  'Listing -> list',
#  'Rules -> rule',
#  'SFO -> sfo',
#  'Takeovers -> takeov',
#  'Code -> code',
#  'Key -> key',
#  'Achievement -> achiev',
#  'Assisted -> assist',
#  'acquisition -> acquisit',
#  '50 -> 50',
#  'interest -> interest',
#  'China -> china',
#  'Gold -> gold',
#  'Silver -> silver',
#  'Group -> group',
#  'Company -> compani',
#  'Limited -> limit',
#  '3D-GOLD -> 3d-gold',
#  'Developed -> develop',
#  'implemented -> implement',
#  'Guideline -> guidelin',
#  'Securities -> secur',
#  'Transactions -> transact',
#  'Directors -> director',
#  'Relevant -> relev',
#  'MAR -> mar',
#  '2013 -> 2013',
#  'JUL -> jul',
#  '2013 -> 2013',
#  'Intertrust -> intertrust',
#  'Group -> group',
#  'Semi -> semi',
#  'Senior -> senior',
#  'Employees -> employe',
#  'group -> group',
#  'Handled -> handl',
#  'incorporation -> incorpor',
#  'companies -> compani',
#  'Processed -> process',
#  'share -> share',
#  'transfers -> transfer',
#  'directors -> director',
#  'Prepared -> prepar',
#  'annual -> annual',
#  'return -> return',
#  'tax -> tax',
#  'return -> return',
#  'statutory -> statutori',
#  'documents -> document',
#  'Maintained -> maintain',
#  'statutory -> statutori',
#  'registers -> regist',
#  'companies -> compani',
#  'Arranged -> arrang',
#  'opening -> open',
#  'bank -> bank',
#  'accounts -> account',
#  'JUL -> jul',
#  '2010 -> 2010',
#  'MAR -> mar',
#  '2013 -> 2013',
#  'Tricor -> tricor',
#  'Services -> servic',
#  'Limited -> limit',
#  'Officer -> offic',
#  'Provided -> provid',
#  'full -> full',
#  'spectrum -> spectrum',
#  'company -> compani',
#  'secretarial -> secretari',
#  'advisory -> advisori',
#  'services -> servic',
#  'listed -> list',
#  'clients -> client',
#  'Reviewed -> review',
#  'annual -> annual',
#  'interim -> interim',
#  'reports -> report',
#  'announcements -> announc',
#  'circulars -> circular',
#  'Reviewed -> review',
#  'IPO -> ipo',
#  'prospectus -> prospectu',
#  'application -> applic',
#  'forms -> form',
#  'Prepared -> prepar',
#  'annual -> annual',
#  'return -> return',
#  'tax -> tax',
#  'return -> return',
#  'statutory -> statutori',
#  'documents -> document',
#  'Liaised -> liais',
#  'banks -> bank',
#  'prepared -> prepar',
#  'bank -> bank',
#  'account -> account',
#  'opening -> open',
#  'documents -> document',
#  'Handled -> handl',
#  'ad-hoc -> ad-hoc',
#  'assignments -> assign',
#  'alternation -> altern',
#  'M -> M',
#  'A -> A',
#  'change -> chang',
#  'company -> compani',
#  'names -> name',
#  'Key -> key',
#  'Achievement -> achiev',
#  'EDUCATION -> educ',
#  'Assisted -> assist',
#  'IPO -> ipo',
#  'Chow -> chow',
#  'Tai -> tai',
#  'Fuk -> fuk',
#  'Jewellery -> jewelleri',
#  'Group -> group',
#  'Limited -> limit',
#  '2012 -> 2012',
#  '2016 -> 2016',
#  '2018 -> 2018',
#  'Master -> master',
#  'Corporate -> corpor',
#  'Governance -> govern',
#  'The -> the',
#  'Hong -> hong',
#  'Kong -> kong',
#  'Polytechnic -> polytechn',
#  'University -> univers',
#  '2012 -> 2012',
#  '2015 -> 2015',
#  'Bachelor -> bachelor',
#  'Business -> busi',
#  'Administration -> administr',
#  'Hons -> hon',
#  'Corporate -> corpor',
#  'Administration -> administr',
#  'The -> the',
#  'Open -> open',
#  'University -> univers',
#  'Hong -> hong',
#  'Kong -> kong',
#  '2008 -> 2008',
#  '2010 -> 2010',
#  'Associate -> associ',
#  'Arts -> art',
#  'English -> english',
#  'Business -> busi',
#  'Communication -> commun',
#  '2003 -> 2003',
#  '2005 -> 2005',
#  'S -> S',
#  'K -> K',
#  'H -> H',
#  'Li -> Li',
#  'Ping -> ping',
#  'Secondary -> secondari',
#  'School -> school',
#  'Secondary -> secondari',
#  '6-7 -> 6-7',
#  'The -> the',
#  'Hong -> hong',
#  'Kong -> kong',
#  'Polytechnic -> polytechn',
#  'University -> univers',
#  'Hong -> hong',
#  'Kong -> kong',
#  'Community -> commun',
#  'College -> colleg',
#  'Obtained -> obtain',
#  'A -> A',
#  'Reading -> read',
#  'Language -> languag',
#  'Systems -> system',
#  'Use -> use',
#  'English -> english',
#  'HKALE -> hkale',
#  '2005 -> 2005',
#  '1998 -> 1998',
#  '2003 -> 2003',
#  'Po -> Po',
#  'Leung -> leung',
#  'Kuk -> kuk',
#  'Lee -> lee',
#  'Shing -> shing',
#  'Pik -> pik',
#  'College -> colleg',
#  'Secondary -> secondari',
#  '1-5 -> 1-5',
#  'REFERENCES -> refer',
#  'AVAILABLE -> avail',
#  'ON -> ON',
#  'REQUEST -> request',
#  '1 -> 1',
#  'SKILLS -> skill',
#  'CHOW -> chow',
#  'SHING -> shing',
#  'LUNG -> lung',
#  'CHESTER -> chester',
#  'Address -> address',
#  '24D -> 24d',
#  'Kwai -> kwai',
#  'Chung -> chung',
#  'Fa -> Fa',
#  'Yuen -> yuen',
#  '52 -> 52',
#  'Wo -> Wo',
#  'Yi -> Yi',
#  'Hop -> hop',
#  'Road -> road',
#  'Kwai -> kwai',
#  'Chung -> chung',
#  'N -> N',
#  'T -> T',
#  'Tel -> tel',
#  '852 -> 852',
#  '9279 -> 9279',
#  '7979 -> 7979',
#  'Email -> email',
#  'chester -> chester',
#  'sl -> sl',
#  'chow -> chow',
#  'gmail -> gmail',
#  'Language -> languag',
#  'Excellent -> excel',
#  'command -> command',
#  'written -> written',
#  'English -> english',
#  'British -> british',
#  'Chinese -> chines',
#  'traditional -> tradit',
#  'simplified -> simplifi',
#  'Fluent -> fluent',
#  'spoken -> spoken',
#  'English -> english',
#  'Cantonese -> cantones',
#  'Putonghua -> putonghua',
#  'Computer -> comput',
#  'CSA -> csa',
#  'MS -> MS',
#  'Word -> word',
#  'Excel -> excel',
#  'Power -> power',
#  'Point -> point',
#  'English -> english',
#  'Chinese -> chines',
#  'Word -> word',
#  'Processing -> process',
#  'Typing -> type',
#  'English -> english',
#  '70 -> 70',
#  'wpm -> wpm',
#  'Chinese -> chines',
#  '60 -> 60',
#  'wpm -> wpm',
#  'SALARY -> salari',
#  'Current -> current',
#  'HK -> HK',
#  ...]

# %% [markdown]
# ##### * Rare tokens (with the threshold set to %2) must be removed from the vocab.
# 移除整理後最後2%的字（較少用到的字）

# %%
# # 詞彙的多樣性
# # set: no repeat, no order
# def lexical_diversity(text):
#     return len(set(text)) / len(text)

# a function for getting the percentage of each token frequency
def percentage(count, total):
    return 100 * (count / total)

# distinct tokens remaining filtered from filtered_tokens
lexical_diversity = set(filtered_tokens)

# create an empty list
often_tokens = []
tidy_tokens = []
# check each distinct token
for each in lexical_diversity: 
    # calculate the percentage of each token frequency
    token_ratio = percentage(filtered_tokens.count(each), len(tokens))
#     print(each, ":", token_ratio)
    # if the token frequency(%) is greater than 2%
    if token_ratio > 0.02:
        # add into often_tokens
        often_tokens.append(each)
# sorted often_tokens excludes the rare tokens (2%)
print(sorted(often_tokens))
# Out:
# ['000', '02', '05', '06', '07', '08', '0800', '1', '1-5', '1-HNSP', '1-month', '100', '11', '12', '129', '13', '134821', '14', '15Mn', '15th', '16', '17', '18', '1981', '1998', '1Mn', '1st', '2', '20', '2003', '2005', '2007', '2008', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2018', '22', '220Mn', '23rd', '246', '248', '24D', '250Mn', '26', '28th', '2nd', '3', '305', '30th', '31st', '340', '36', '37Mn', '3D-GOLD', '3⅓', '4', '4161', '45', '48', '4th', '4¼', '5', '50', '500', '52', '6', '6-7', '60', '6020', '61', '63', '654', '6748-8526', '6th', '7', '70', '73', '7979', '8', '852', '85Mn', '8Mn', '8th', '9', '9279', '9582697', '971', 'A', 'ACADEMIC', 'ACCA', 'ACI', 'ACTIVITIES', 'AGTech', 'AIA', 'AMD', 'ATMI', 'AUM', 'AVAILABILITY', 'AVAILABLE', 'AVERAGE', 'AVP', 'Academic', 'Access', 'Accountancy', 'Accountant', 'Accountants', 'Accounting', 'Achievement', 'Achievements', 'Address', 'Administration', 'Advanced', 'Advised', 'Advisor', 'Ahli', 'Al', 'Alibaba', 'All', 'An', 'Analysis', 'Analyze', 'Analyzing', 'Applied', 'Apr', 'Arranged', 'Arts', 'Assessing', 'Asset', 'Assignment', 'Assist', 'Assistant', 'Assisted', 'Assoc', 'Associate', 'Associates', 'Association', 'Assurance', 'Auditor', 'Aug', 'Aust', 'Australia', 'Authority', 'Average', 'BSc', 'BU', 'Bachelor', 'Bank', 'Banking', 'Banks', 'Best', 'Birth', 'Board', 'Bond', 'British', 'Brookes', 'Built', 'Business', 'CBFS', 'CEO', 'CGMA', 'CHESTER', 'CHOW', 'CISI', 'CPA', 'CREDENTIALS', 'CSA', 'CSE', 'CURRENT', 'Cantonese', 'Capital', 'Cement', 'Central', 'Certificate', 'Certifications', 'Certified', 'Chairperson', 'Chartered', 'Cheer', 'Chengdu', 'Chief', 'China', 'Chinese', 'Chow', 'Chung', 'City', 'Class', 'Co', 'Code', 'Collaborating', 'College', 'Colombo', 'Commission', 'Committee', 'Communication', 'Community', 'Companies', 'Company', 'Completed', 'Comprehensive', 'Computer', 'Conducted', 'Conducting', 'Constructed', 'Corporate', 'Corporates', 'Corporation', 'Council', 'Credentials', 'Current', 'Curriculum', 'DETAILS', 'DPM', 'Date', 'Dealer', 'Debt', 'Dec', 'Degree', 'Derivatives', 'Developed', 'Development', 'Directors', 'Discretionary', 'Division', 'Dubai', 'EDUCATION', 'ETFs', 'EVP', 'EXPECTED', 'EXPERIENCE', 'EXTRA-CURRICULAR', 'Eikon', 'Election', 'Email', 'Emotional', 'Employees', 'English', 'Enhancer', 'Equities', 'Equity', 'Ernst', 'Established', 'Euro', 'Excel', 'Excellent', 'Exchange', 'Executive', 'Expected', 'Experience', 'Experiences', 'Exploration', 'FCMA', 'FEB', 'FICO', 'FINCORP', 'Fa', 'Family', 'Feb', 'Fellow', 'Financ', 'Finance', 'Financial', 'Firm', 'First', 'Fixed', 'Fluent', 'Fook', 'Fortune', 'Fuk', 'Fund', 'Funds', 'GCC', 'GECS', 'GMPI', 'GRIP', 'Generated', 'Glass', 'Global', 'Gold', 'Governance', 'Government', 'Gowribalan', 'Grew', 'Group', 'Guideline', 'Gulf', 'H', 'HILIGHTS', 'HK', 'HKALE', 'HKFRS', 'HNB', 'HNI', 'HSBC', 'Hall', 'Handled', 'Hatton', 'Head', 'Health', 'Hedge', 'Held', 'Holding', 'Holdings', 'Honed', 'Hong', 'Honours', 'Hons', 'Hop', 'I', 'IPO', 'IPOs', 'Income', 'Individual', 'Information', 'Institute', 'Insurance', 'Intelligence', 'Internal', 'International', 'Intertrust', 'Inve', 'Investment', 'Involved', 'Islamic', 'JUL', 'Jan', 'January', 'Jazeera', 'Jewellery', 'Jul', 'Jun', 'June', 'K', 'Ken', 'Keung', 'Key', 'Kin', 'Knowledge', 'Kong', 'Kothari', 'Kuk', 'Kwai', 'L', 'LUNG', 'Language', 'Languages', 'Lanka', 'Large', 'Lee', 'Leung', 'Li', 'Liaise', 'Liaised', 'Limited', 'Link', 'Listing', 'Ltd', 'Luk', 'M', 'MAR', 'MCSI', 'MENA', 'MGCI', 'MGH', 'MPFA', 'MS', 'Made', 'Maintained', 'Majan', 'Management', 'Manager', 'Mar', 'Market', 'Master', 'Mater', 'Mathematics', 'Member', 'Membership', 'Merit', 'Mn', 'Mobile', 'Money', 'Mths', 'Mushroom', 'Mutual', 'N', 'NDA', 'Nat', 'National', 'Native', 'No', 'Notes', 'Nov', 'OCOI', 'OIBB', 'ON', 'ONIC', 'ORGANISATION', 'OSCI', 'OTEL', 'Obtained', 'Oct', 'Office', 'Officer', 'Oman', 'Omantel', 'Open', 'Operational', 'Others', 'Oversight', 'Oxford', 'P', 'PERSONAL', 'PRESE ...

# %%
from nltk.probability import *
fd_1 = FreqDist(filtered_tokens)
fd_1.most_common(5) # The list contains the 25 most frequent words.
# Out:
# [('Management', 14),
#  ('management', 14),
#  ('fund', 12),
#  ('risk', 11),
#  ('SAOG', 11)]

# %%
# after organizing
print("The total number of tokens:", len(tokens))
print("The total number of distinct tokens:", len(set(filtered_tokens)))
print("The lexical diversity:", len(tokens)/len(set(filtered_tokens)))
# Out:
# The total number of tokens: 2452
# The total number of distinct tokens: 1020
# The lexical diversity: 2.403921568627451

# %% [markdown]
# ##### * Tokens must be normalized to lowercase except the capital tokens appeared in the middle<br> of a sentence/line.
# 全變成小寫（除了專有名詞ex:PowerNet）

# %%
c1 = [1, 6, 7, 10, 13, 28, 32, 41, 58, 63]
c2 = [[13, 17, 18, 21, 32], [7, 11, 13, 14, 28], [1, 5, 6, 8, 15, 16]]
c3 = [list(filter(lambda x: x in c1, sublist)) for sublist in c2]
c3
# Out:
# [[13, 32], [7, 13, 28], [1, 6]]

# %%
# list of alphabets
alphabets = ['a', 'b', 'd', 'e', 'i', 'j', 'o']

# function that filters vowels
def filterVowels(alphabet):
    vowels = ['a', 'e', 'i', 'o', 'u']

    if(alphabet in vowels):
        return True
    else:
        return False

filteredVowels = filter(filterVowels, alphabets)

result = ''
print('The filtered vowels are:')
for vowel in filteredVowels:
    result += vowel+' '
print(result)
# Out:
# The filtered vowels are:
# a e i o

# %%
# 卡題
# regex for the Camelcase
#r'(?<!\.\s)\b[A-Z][a-z]*\b' # get the capital tokens appeared in the middle
#camel_case = r"([A-Z][a-z]+[A-Z][a-z]+)"

# regex for getting those capital tokens in the middle of the sentences 
capita_tokens = r'(?<!\.\s)(\b[A-Z](?:[A-Z]*|[a-z]*)\b|\b[A-Z][a-z]+[A-Z][a-z]+\b)'
# capita_first_tokens = r'(?:^|(?:\W\s))([A-Z]\w+)'
# 包含句首那個字也算入 r'(?:(?<!\.\s)(\b[A-Z](?:[A-Z]*|[a-z]*)\b|\b[A-Z][a-z]+[A-Z][a-z]+\b))|(?:(?:^|(?:\W\s))([A-Z]\w+))'

match_capital = re.findall(capital_tokens, clean_string)
# match_capital

# create an empty string
result = ''
# check each token in tokens
for token in tokens:
    # if that token not in the middle of the sentences
    if token not in match_capital:
        # make it lowercase and then add into result
        result += token.lower() + ' '
    else:
        # or directly add into result
        result += token + ' '
print(result)

# # 順序會亂掉，但留下來的是對的值
# match_capital_set = set(match_capital)
# tokens_set = set(tokens)
# print(tokens_set-match_capital_set)
# Out:
# WAN Kin Keung Ken Mobile 852 6748-8526 Email kinkeung0531 gmail com PERSONAL SUMMARY 4 years working experience half year in CPA firm and 3 5 years fund operation experiences in AIA 2 years supervising experiences Involved in due auditing engagements in logistics industry trading and manufacturing industries and consultation services company Experiences in fund operation valuation regulatory reporting and financial analysis Knowledge for internal controls and risk monitoring WORK EXPERIENCE Mar 2016 Present Senior Associate Accounting and Finance AIA Support the daily operation valuation processes and fund daily monitoring Support the regulatory reporting to MPFA Analyze results and monitoring performance metrics against benchmark forecast and historical trends Support the budgeting for funds operation Liaise and cooperate with internal departments risk and compliance products sales agency customer services external auditors MPFA SFC investment managers etc Review and restructure the working procedures to improve the operation efficiency Support firm wide and departmental projects such as new product launch scheme merger streamline workflow processes within the BU etc Associate Accounting and Finance AIA Support fund valuation team to perform daily fund operation and valuation processes Analyzing operations and fund performance results monitoring variances Conducting analytical reviews on financial transaction to identify unusual price fluctuations Assessing the internal control procedure and compliance requirements Reviewing the appropriateness and completeness of financial statements and accounts disclosures under HKFRS Liaise and cooperate with external auditors compliance departments SFC and MPFA Assist Manager for special projects team for project planning analysis system transformation and UAT Jan 2014 Feb 2016 Aug 2013 Dec 2013 Auditor Cheer Link CPA Limited Assignment to audit engagements for clients with different natures and sizes of business Conducting analytical reviews on financial statements and to identify unusual fluctuations and potential risk exposure Reviewing the appropriateness and completeness of financial statements and accounts disclosures under HKFRS Solid understanding of accounting process by performing walkthrough and validating the relevant control procedures Assessing the fair values on private equities and other financial derivatives with various valuation methodology Conducting sensitivity analysis to evaluate market price risk interest rate risk credit risk and liquidity risk Collaborating with tax department on corporate tax issues EDUCATION City University of Hong Kong Aug 2010 Jul 2013 Bachelor of Business Administration Honours in Accountancy and Management Information Systems Tin Shui Wai Government Secondary School Sept 2003 Jun 2010 extra-curricular ACTIVITIES 2012 13 2011 12 2010 11 Chairperson Election Board of HSBC Prosperity Hall Chairperson Residents Association Council President Residents Association Executive Committee PROFESSIONAL QUALIFICATIONS 07 2010 Present Student Member of Hong Kong Institute of Certified Public Accountants SPECIAL SKILLS Languages Fluent English written spoken Native Chinese written spoken Fluent Putonghua Strengths Strong interpersonal skill and communication skill quick learner and highly adaptable to change strong analytical skills and problem solving skill others Advanced MS Office Excel Word PowerPoint Access Chinese English word processing CURRENT SALARY HK 22 000 per month included allowance EXPECTED SALARY HK 26 000 per month AVAILABILITY 1-month notice YANG TAMMIE QI 杨 琪 Email qyangaf gmail com Mobile 852 6020 4161 HILIGHTS Completed ACCA professional examinations Mater degree holding in Accounting Accounting experience in financial industries Fortune 500 company Research background especially in real estate industry Comprehensive hedge fund operation knowledge EDUCATION The Hong Kong University of Science and Technology Master of Accounting Sichu ...

# %% [markdown]
# ##### * Tokens with the length less than 3 should be removed from the vocab.
# 移除字數小於3個 ex: am

# %%
token_3more_len_list = []
for each in filtered_tokens:
    if len(each) >= 3:
        token_3more_len_list.append(each)
print(token_3more_len_list)
# Out:
# ['WAN', 'Kin', 'Keung', 'Ken', 'Mobile', '852', '6748-8526', 'Email', 'kinkeung0531', 'gmail', 'PERSONAL', 'SUMMARY', 'years', 'working', 'experience', 'half', 'year', 'CPA', 'firm', 'years', 'fund', 'operation', 'experiences', 'AIA', 'years', 'supervising', 'experiences', 'Involved', 'due', 'auditing', 'engagements', 'logistics', 'industry', 'trading', 'manufacturing', 'industries', 'consultation', 'services', 'company', 'Experiences', 'fund', 'operation', 'valuation', 'regulatory', 'reporting', 'financial', 'analysis', 'Knowledge', 'internal', 'controls', 'risk', 'monitoring', 'WORK', 'EXPERIENCE', 'Mar', '2016', 'Present', 'Senior', 'Associate', 'Accounting', 'Finance', 'AIA', 'Support', 'daily', 'operation', 'valuation', 'processes', 'fund', 'daily', 'monitoring', 'Support', 'regulatory', 'reporting', 'MPFA', 'Analyze', 'results', 'monitoring', 'performance', 'metrics', 'benchmark', 'forecast', 'historical', 'trends', 'Support', 'budgeting', 'funds', 'operation', 'Liaise', 'cooperate', 'internal', 'departments', 'risk', 'compliance', 'products', 'sales', 'agency', 'customer', 'services', 'external', 'auditors', 'MPFA', 'SFC', 'investment', 'managers', 'Review', 'restructure', 'working', 'procedures', 'improve', 'operation', 'efficiency', 'Support', 'firm', 'wide', 'departmental', 'projects', 'product', 'launch', 'scheme', 'merger', 'streamline', 'workflow', 'processes', 'Associate', 'Accounting', 'Finance', 'AIA', 'Support', 'fund', 'valuation', 'team', 'perform', 'daily', 'fund', 'operation', 'valuation', 'processes', 'Analyzing', 'operations', 'fund', 'performance', 'results', 'monitoring', 'variances', 'Conducting', 'analytical', 'reviews', 'financial', 'transaction', 'identify', 'unusual', 'price', 'fluctuations', 'Assessing', 'internal', 'control', 'procedure', 'compliance', 'requirements', 'Reviewing', 'appropriateness', 'completeness', 'financial', 'statements', 'accounts', 'disclosures', 'HKFRS', 'Liaise', 'cooperate', 'external', 'auditors', 'compliance', 'departments', 'SFC', 'MPFA', 'Assist', 'Manager', 'special', 'projects', 'team', 'project', 'planning', 'analysis', 'system', 'transformation', 'UAT', 'Jan', '2014', 'Feb', '2016', 'Aug', '2013', 'Dec', '2013', 'Auditor', 'Cheer', 'Link', 'CPA', 'Limited', 'Assignment', 'audit', 'engagements', 'clients', 'natures', 'sizes', 'business', 'Conducting', 'analytical', 'reviews', 'financial', 'statements', 'identify', 'unusual', 'fluctuations', 'potential', 'risk', 'exposure', 'Reviewing', 'appropriateness', 'completeness', 'financial', 'statements', 'accounts', 'disclosures', 'HKFRS', 'Solid', 'understanding', 'accounting', 'process', 'performing', 'walkthrough', 'validating', 'relevant', 'control', 'procedures', 'Assessing', 'fair', 'values', 'private', 'equities', 'financial', 'derivatives', 'valuation', 'methodology', 'Conducting', 'sensitivity', 'analysis', 'evaluate', 'market', 'price', 'risk', 'interest', 'rate', 'risk', 'credit', 'risk', 'liquidity', 'risk', 'Collaborating', 'tax', 'department', 'corporate', 'tax', 'issues', 'EDUCATION', 'City', 'University', 'Hong', 'Kong', 'Aug', '2010', 'Jul', '2013', 'Bachelor', 'Business', 'Administration', 'Honours', 'Accountancy', 'Management', 'Information', 'Systems', 'Tin', 'Shui', 'Wai', 'Government', 'Secondary', 'School', 'Sept', '2003', 'Jun', '2010', 'EXTRA-CURRICULAR', 'ACTIVITIES', '2012', '2011', '2010', 'Chairperson', 'Election', 'Board', 'HSBC', 'Prosperity', 'Hall', 'Chairperson', 'Residents', 'Association', 'Council', 'President', 'Residents', 'Association', 'Executive', 'Committee', 'PROFESSIONAL', 'QUALIFICATIONS', '2010', 'Present', 'Student', 'Member', 'Hong', 'Kong', 'Institute', 'Certified', 'Public', 'Accountants', 'SPECIAL', 'SKILLS', 'Languages', 'Fluent', 'English', 'written', 'spoken', 'Native', 'Chinese', 'written', 'spoken', 'Fluent', 'Putonghua', 'Strengths', 'Strong', 'interpersonal', 'skill', 'communication', 'skill', 'quick', 'learner', 'highly', 'adaptable', 'change', 'strong', 'analytic ...

# %%
print(len(filtered_tokens))
print(len(token_3more_len_list))
# Out:
# 1981
# 1797

# %% [markdown]
# ##### * First 200 meaningful bigrams (i.e., collocations) must be included in the vocab.
# 剩下的字中，前200的bigram<br>
# ex: I am/ soy milk/ google map 兩個兩個字

# %%
from nltk.util import ngrams

# create an empty string
non_sign = ''
# check each token in tokens
for each in tokens:
    # if each token is an alphabet
    if each.isalpha():
        # add it into non_sign
        non_sign += each + " "
        
# get bigrams
bigrams = ngrams(non_sign.split(), n = 2)
# the frequency of eahc bigram
fdbigram = FreqDist(bigrams)

# %%
# get 200 higher frequency (much more meaningful) bigrams and sort
sorted(fdbigram.most_common(n=200))
# Out:
# [(('AIA', 'Support'), 2),
#  (('AVAILABILITY', 'notice'), 2),
#  (('AVAILABLE', 'ON'), 2),
#  (('Accountants', 'U'), 2),
#  (('Accounting', 'and'), 2),
#  (('Achievement', 'Assisted'), 2),
#  (('Address', 'Kwai'), 2),
#  (('Ahli', 'Bank'), 3),
#  (('Applied', 'Accounting'), 2),
#  (('Assessing', 'the'), 2),
#  (('Asset', 'Management'), 3),
#  (('Assisted', 'in'), 3),
#  (('Associate', 'Accounting'), 2),
#  (('BSc', 'Hons'), 3),
#  (('Bachelor', 'of'), 2),
#  (('Bank', 'SAOG'), 4),
#  (('Business', 'Administration'), 2),
#  (('CHESTER', 'Address'), 2),
#  (('CHOW', 'SHING'), 2),
#  (('CPA', 'Aust'), 2),
#  (('Capital', 'Market'), 3),
#  (('Certified', 'Practising'), 2),
#  (('Chartered', 'Global'), 2),
#  (('Chartered', 'Institute'), 4),
#  (('Chengdu', 'China'), 3),
#  (('Chung', 'Fa'), 2),
#  (('Chung', 'N'), 2),
#  (('Co', 'Ltd'), 2),
#  (('Co', 'SAOG'), 4),
#  (('Company', 'Secretarial'), 2),
#  (('Conducting', 'analytical'), 2),
#  (('Curriculum', 'Vitae'), 3),
#  (('EXPERIENCE', 'YEARS'), 2),
#  (('Email', 'chester'), 2),
#  (('Fa', 'Yuen'), 2),
#  (('Fellow', 'of'), 2),
#  (('Finance', 'AIA'), 2),
#  (('First', 'Class'), 2),
#  (('GCC', 'region'), 3),
#  (('Global', 'Management'), 2),
#  (('Group', 'Company'), 2),
#  (('Group', 'Limited'), 2),
#  (('HK', 'per'), 2),
#  (('Head', 'of'), 2),
#  (('Hong', 'Kong'), 9),
#  (('Hop', 'Road'), 2),
#  (('IPO', 'of'), 2),
#  (('Institute', 'of'), 5),
#  (('Key', 'Achievement'), 3),
#  (('Kong', 'Polytechnic'), 2),
#  (('Kong', 'Sep'), 2),
#  (('Kwai', 'Chung'), 4),
#  (('LUNG', 'CHESTER'), 2),
#  (('Liaise', 'and'), 2),
#  (('M', 'A'), 2),
#  (('Management', 'Accountant'), 2),
#  (('Management', 'Accountants'), 2),
#  (('Master', 'of'), 2),
#  (('Member', 'of'), 3),
#  (('N', 'T'), 2),
#  (('ON', 'REQUEST'), 2),
#  (('Oct', 'Feb'), 2),
#  (('PROFESSIONAL', 'EXPERIENCE'), 2),
#  (('Polytechnic', 'University'), 2),
#  (('Practising', 'Accountant'), 2),
#  (('Prepared', 'annual'), 2),
#  (('REFERENCES', 'AVAILABLE'), 2),
#  (('Reported', 'to'), 4),
#  (('Residents', 'Association'), 2),
#  (('Return', 'p'), 3),
#  (('Reviewing', 'the'), 2),
#  (('Road', 'Kwai'), 2),
#  (('SALARY', 'HK'), 2),
#  (('SAOG', 'www'), 2),
#  (('SHING', 'LUNG'), 2),
#  (('Secondary', 'School'), 2),
#  (('Secretarial', 'Officer'), 2),
#  (('Securities', 'and'), 4),
#  (('Sri', 'Lanka'), 4),
#  (('Support', 'the'), 3),
#  (('T', 'Tel'), 2),
#  (('Tel', 'Email'), 2),
#  (('The', 'Hong'), 3),
#  (('To', 'review'), 2),
#  (('U', 'K'), 4),
#  (('USD', 'Mn'), 5),
#  (('University', 'Bachelor'), 2),
#  (('University', 'of'), 4),
#  (('WORK', 'EXPERIENCE'), 2),
#  (('Wo', 'Yi'), 2),
#  (('Yi', 'Hop'), 2),
#  (('Yrs', 'Oct'), 2),
#  (('Yuen', 'Wo'), 2),
#  (('accounts', 'disclosures'), 2),
#  (('across', 'the'), 2),
#  (('agent', 'USD'), 3),
#  (('analytical', 'reviews'), 2),
#  (('and', 'Chinese'), 2),
#  (('and', 'Finance'), 2),
#  (('and', 'Investment'), 3),
#  (('and', 'accounts'), 2),
#  (('and', 'circulars'), 2),
#  (('and', 'completeness'), 2),
#  (('and', 'compliance'), 2),
#  (('and', 'connected'), 2),
#  (('and', 'cooperate'), 2),
#  (('and', 'fund'), 2),
#  (('and', 'other'), 3),
#  (('and', 'prepared'), 2),
#  (('announcements', 'and'), 2),
#  (('annual', 'interim'), 2),
#  (('annual', 'return'), 2),
#  (('appropriateness', 'and'), 2),
#  (('average', 'over'), 2),
#  (('chester', 'sl'), 2),
#  (('chow', 'gmail'), 2),
#  (('collecting', 'agent'), 4),
#  (('com', 'Mobile'), 4),
#  (('com', 'vgowribalan'), 3),
#  (('company', 'secretarial'), 2),
#  (('completeness', 'of'), 2),
#  (('compliance', 'with'), 2),
#  (('connected', 'transactions'), 2),
#  (('cooperate', 'with'), 2),
#  (('daily', 'operation'), 2),
#  (('debt', 'securities'), 2),
#  (('disclosures', 'under'), 2),
#  (('e', 'mail'), 3),
#  (('equities', 'and'), 2),
#  (('especially', 'in'), 2),
#  (('external', 'auditors'), 2),
#  (('financial', 'statements'), 4),
#  (('fixed', 'income'), 2),
#  (('for', 'the'), 5),
#  (('for', 'three'), 2),
#  (('full', 'spectrum'), 2),
#  (('fund', 'operation'), 4),
#  (('gmail', 'com'), 7),
#  (('identify', 'unusual'), 2),
#  (('in', 'Accounting'), 2),
#  (('in', 'real'), 2),
#  (('in', 'the'), 5),
#  (('interim', 'reports'), 2),
#  (('internal', 'control'), 2),
#  (('investment', 'managers'), 2),
#  (('listed', 'companies'), 2),
#  (('listed', 'equities'), 2),
#  (('live', 'com'), 3),
#  (('mail', 'vgowribalan'), 3),
#  (('management', 'and'), 2),
#  (('meetings', 'and'), 2),
#  (('mutual', 'fund'), 2),
#  (('of', 'Asset'), 2),
#  (('of', 'Business'), 2),
#  (('of', 'Hong'), 3),
#  (('of', 'Management'), 2),
#  (('of', 'Securities'), 2),
#  (('of', 'company'), 3),
#  (('of', 'directors'), 2),
#  (('of', 'financial'), 2),
#  (('of', 'p'), 3),
#  (('of', 'the'), 8),
#  (('on', 'financial'), 2),
#  (('operation', 'valuation'), 2),
#  (('other', 'statutory'), 2),
#  (('over', 'the'), 2),
#  (('p', 'a'), 12),
#  (('per', 'month'), 2),
#  (('portfolio', 'management'), 4),
#  (('process', 'by'), 2),
#  (('real', 'estate'), 2),
#  (('regulatory', 'reporting'), 2),
#  (('return', 'and'), 2),
#  (('return', 'tax'), 2),
#  (('reviews', 'on'), 2),
#  (('risk', 'and'), 2),
#  (('risk', 'management'), 2),
#  (('sl', 'chow'), 2),
#  (('spanning', 'the'), 2),
#  (('spectrum', 'of'), 2),
#  (('statements', 'and'), 4),
#  (('statutory', 'documents'), 2),
#  (('such', 'as'), 2),
#  (('tax', 'return'), 2),
#  (('the', 'Chartered'), 4),
#  (('the', 'GCC'), 4),
#  (('the', 'appropriateness'), 2),
#  (('the', 'group'), 2),
#  (('to', 'identify'), 2),
#  (('to', 'the'), 4),
#  (('transactions', 'and'), 2),
#  (('under', 'HKFRS'), 2),
#  (('under', 'management'), 5),
#  (('valuation', 'processes'), 2),
#  (('vgowribalan', 'gmail'), 3),
#  (('vgowribalan', 'live'), 3),
#  (('wealth', 'management'), 3),
#  (('with', 'the'), 2),
#  (('within', 'the'), 2),
#  (('written', 'spoken'), 2)]

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = nltk.collocations.BigramCollocationFinder.from_words(non_sign.split())
finder.nbest(bigram_measures.pmi, 200)
# Out:
# [('ATMI', 'Telecom'),
#  ('AVERAGE', 'RETURN'),
#  ('Advisor', 'Derivatives'),
#  ('Al', 'Jazeera'),
#  ('All', 'View'),
#  ('An', 'increase'),
#  ('Analyzing', 'operations'),
#  ('Assoc', 'iation'),
#  ('Authority', 'stipulated'),
#  ('Best', 'Performing'),
#  ('Birth', 'January'),
#  ('CBFS', 'Colombo'),
#  ('CREDENTIALS', 'Academic'),
#  ('Cheer', 'Link'),
#  ('Chow', 'Tai'),
#  ('Colombo', 'Stock'),
#  ('Comprehensive', 'hedge'),
#  ('Computer', 'CSA'),
#  ('Corporates', 'Family'),
#  ('Credentials', 'include'),
#  ('Dealer', 'Emotional'),
#  ('Division', 'AMD'),
#  ('Dubai', 'UAE'),
#  ('ETFs', 'Returns'),
#  ('EVP', 'formulated'),
#  ('Eikon', 'Zawya'),
#  ('Election', 'Board'),
#  ('Emotional', 'Intelligence'),
#  ('Enhancer', 'Series'),
#  ('Excellent', 'command'),
#  ('Experience', 'includes'),
#  ('FEB', 'Luk'),
#  ('Fuk', 'Jewellery'),
#  ('Funds', 'Banks'),
#  ('GRIP', 'holistic'),
#  ('Generated', 'realised'),
#  ('Glass', 'MGCI'),
#  ('Gold', 'Silver'),
#  ('H', 'Li'),
#  ('HILIGHTS', 'Completed'),
#  ('HKALE', 'Po'),
#  ('HNI', 'Individual'),
#  ('HSBC', 'Prosperity'),
#  ('Hatton', 'Nat'),
#  ('Honed', 'expertise'),
#  ('I', 'led'),
#  ('Individual', 'investors'),
#  ('Intelligence', 'CBFS'),
#  ('Inve', 'stment'),
#  ('January', 'Resident'),
#  ('Keung', 'Ken'),
#  ('Kin', 'Keung'),
#  ('Kuk', 'Lee'),
#  ('L', 'reconciliations'),
#  ('Large', 'Corporates'),
#  ('Lee', 'Shing'),
#  ('Leung', 'Kuk'),
#  ('Li', 'Ping'),
#  ('Listing', 'Rules'),
#  ('Luk', 'Fook'),
#  ('Made', 'timely'),
#  ('Majan', 'Glass'),
#  ('Mater', 'degree'),
#  ('Merit', 'Pass'),
#  ('NDA', 'employment'),
#  ('Nat', 'ional'),
#  ('ORGANISATION', 'TENURE'),
#  ('OTEL', 'Worked'),
#  ('Others', 'Advanced'),
#  ('P', 'L'),
#  ('Pension', 'Funds'),
#  ('Personal', 'development'),
#  ('Plan', 'GRIP'),
#  ('Platform', 'competence'),
#  ('Po', 'Leung'),
#  ('Policy', 'holders'),
#  ('PowerPoint', 'Access'),
#  ('Processed', 'share'),
#  ('Processing', 'Typing'),
#  ('Prosperity', 'Hall'),
#  ('QI', '杨'),
#  ('ROLE', 'ORGANISATION'),
#  ('Research', 'background'),
#  ('Resident', 'Dubai'),
#  ('Series', 'YES'),
#  ('Sharia', 'complaint'),
#  ('Shing', 'Pik'),
#  ('Shui', 'Wai'),
#  ('Smartline', 'Training'),
#  ('Solid', 'understanding'),
#  ('Sovereign', 'Sukuk'),
#  ('Sponsor', 'Euro'),
#  ('Strengths', 'Strong'),
#  ('Strong', 'interpersonal'),
#  ('TAMMIE', 'QI'),
#  ('TENURE', 'AVERAGE'),
#  ('Tai', 'Fuk'),
#  ('Takeovers', 'Code'),
#  ('Technical', 'Analysis'),
#  ('Tin', 'Shui'),
#  ('V', 'Gowribalan'),
#  ('Vinod', 'Kothari'),
#  ('WAN', 'Kin'),
#  ('Wai', 'Government'),
#  ('YANG', 'TAMMIE'),
#  ('YES', 'Notes'),
#  ('Yield', 'Enhancer'),
#  ('Zawya', 'Technical'),
#  ('against', 'benchmark'),
#  ('agency', 'customer'),
#  ('agreements', 'NDA'),
#  ('ahlibank', 'om'),
#  ('allocation', 'security'),
#  ('allowance', 'EXPECTED'),
#  ('application', 'forms'),
#  ('are', 'managed'),
#  ('backed', 'notes'),
#  ('banking', 'franchise'),
#  ('benchmark', 'forecast'),
#  ('charges', 'breakdown'),
#  ('client', 'profile'),
#  ('concert', 'parties'),
#  ('country', 'specific'),
#  ('day', 'resident'),
#  ('degree', 'holding'),
#  ('development', 'Platform'),
#  ('division', 'tasked'),
#  ('due', 'auditing'),
#  ('encompassing', 'Pension'),
#  ('enterprises', 'afterwards'),
#  ('examinations', 'Mater'),
#  ('expense', 'though'),
#  ('fair', 'values'),
#  ('fincorp', 'org'),
#  ('first', 'Sharia'),
#  ('following', 'segments'),
#  ('founding', 'employee'),
#  ('generated', 'amounts'),
#  ('guidelines', 'Oversight'),
#  ('half', 'year'),
#  ('handling', 'initial'),
#  ('highly', 'adaptable'),
#  ('historical', 'trends'),
#  ('increased', 'total'),
#  ('initial', 'public'),
#  ('initiated', 'equity'),
#  ('large', 'contracting'),
#  ('launch', 'scheme'),
#  ('lead', 'analyst'),
#  ('local', 'law'),
#  ('ma', 'rket'),
#  ('margin', 'safety'),
#  ('merger', 'streamline'),
#  ('metrics', 'against'),
#  ('monthly', 'or'),
#  ('new', 'product'),
#  ('offering', 'focusing'),
#  ('operators', 'Large'),
#  ('or', 'yearly'),
#  ('parties', 'Established'),
#  ('performing', 'walkthrough'),
#  ('periodical', 'P'),
#  ('platform', 'targeting'),
#  ('problem', 'solving'),
#  ('processing', 'CURRENT'),
#  ('product', 'launch'),
#  ('professional', 'examinations'),
#  ('quick', 'learner'),
#  ('realised', 'gains'),
#  ('recorded', 'exceptional'),
#  ('safety', 'Constructed'),
#  ('sales', 'agency'),
#  ('scheme', 'merger'),
#  ('security', 'universe'),
#  ('segments', 'Banking'),
#  ('self', 'directed'),
#  ('share', 'transfers'),
#  ('specific', 'appendices'),
#  ('stock', 'take'),
#  ('streamline', 'workflow'),
#  ('suit', 'varied'),
#  ('targeting', 'self'),
#  ('though', 'extracting'),
#  ('tolerances', 'I'),
#  ('universe', 'selection'),
#  ('word', 'processing'),
#  ('work', 'out'),
#  ('杨', '琪'),
#  ('ACCA', 'professional'),
#  ('ACTIVITIES', 'Chairperson'),
#  ('AUM', 'demography'),
#  ('AVAILABILITY', 'notice'),
#  ('AVAILABLE', 'ON'),
#  ('Academic', 'Qualifications'),
#  ('Advanced', 'MS'),
#  ('Analysis', 'Reuters'),
#  ('Analyze', 'results'),
#  ('Association', 'Council'),
#  ('Auditor', 'Cheer'),
#  ('Auditor', 'Participated')]
